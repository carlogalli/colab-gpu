# %% [markdown]
# <a href="https://colab.research.google.com/github/carlogalli/colab-gpu/blob/main/jmp_v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# Installation cell
%%capture
%%shell
if ! command -v julia 3>&1 > /dev/null
then
    wget -q 'https://julialang-s3.julialang.org/bin/linux/x64/1.7/julia-1.7.2-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
julia -e 'using Pkg; pkg"add IJulia; precompile;"'
echo 'Done'

# %% [markdown]
# After you run the first cell (the cell directly above this text), go to Colab's menu bar and select **Edit** and select **Notebook settings** from the drop down. Select *Julia 1.7* in Runtime type. You can also select your prefered harwdware acceleration (defaults to GPU).

# %%
VERSION   # print Julia version
# Out:
# v"1.7.2"

# %%
using Pkg
Pkg.add(["CUDA", "Random", "Distributions", "Printf", "BenchmarkTools", "PyPlot", "PrettyTables", "PyCall", "Adapt"]);
ENV["JULIA_CUDA_USE_BINARYBUILDER"] = false
using Random, Distributions, CUDA, Printf, BenchmarkTools, PyPlot, PrettyTables, PyCall, Adapt;

function print_gpu_properties()

    for (i,device) in enumerate(CUDA.devices())
        println("*** General properties for device $i ***")
        name = CUDA.name(device)
        println("Device name: $name")
        major = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_COMPUTE_CAPABILITY_MAJOR)
        minor = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_COMPUTE_CAPABILITY_MINOR)
        println("Compute capabilities: $major.$minor")
        clock_rate = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_CLOCK_RATE)
        println("Clock rate: $clock_rate")
        device_overlap = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_GPU_OVERLAP)
        print("Device copy overlap: ")
        println(device_overlap > 0 ? "enabled" : "disabled")
        kernel_exec_timeout = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_KERNEL_EXEC_TIMEOUT)
        print("Kernel execution timeout: ")
        println(kernel_exec_timeout > 0 ? "enabled" : "disabled")
        # a = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_MAX_BLOCK_DIM_X)
        # d = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_MAX_GRID_DIM_X)       
        a = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_MULTIPROCESSOR_COUNT)
        println("Number of multiprocessors: $a")
        b = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_MAX_BLOCKS_PER_MULTIPROCESSOR)
        println("Max blocks per MP: $b")
        c = CUDA.attribute(device, CUDA.CU_DEVICE_ATTRIBUTE_MAX_THREADS_PER_BLOCK)        
        println("Max threads per block: $c")
        
        println([a b c a*b*c])
    end
end
print_gpu_properties()
# with the falseENV option it takes 117.357304 seconds (35.94 M allocations: 2.301 GiB, 1.29% gc time, 11.71% compilation time)
# without the falseENV option it takes  124.465413 seconds (39.74 M allocations: 2.537 GiB, 1.27% gc time, 12.65% compilation time)


#Pkg.add("CpuId")
#using CpuId
#cpuinfo()

# %% [markdown]
# # JMP functions

# %%
CUDA.allowscalar(false)

# Model Parameters
struct ModelParams
    # Array Parameters
    nB::Int32
    ny::Int32
    T_longterm::Int32
    T_sim::Int32
    T_discard_sim::Int32
    Bgrid_lb::Float32
    Bgrid_ub::Float32

    # Model Parameters
    σ::Float32      # risk aversion
    η::Float32      # MIU curvature
    r::Float32      # intnl risk-free rate
    ρ::Float32      # income process persistence
    σ_ϵ::Float32    # income process error standard deviation
    θ::Float32      # ree-enter probability
    h::Float32      # haircut on debt
    
    β::Float32      # df govt
    β_hh::Float32   # df hh
    α_m::Float32    # MIU scaling factor
    d0::Float32     # linear coefficient on default costadd C
    d1::Float32     # quadratic coefficient on default cost
    λ::Float32      # debt maturity
    κ::Float32      # debt coupon
    ρ_B::Float32    # coefficient of Gumbel debt taste shocks
    ρ_μ::Float32    # coefficient of Gumbel mu_D taste shocks
    ρ_δ::Float32    # coefficient of Gumbel enforcement shocks
end
function build_ModelParams(;
        nB=51, ny=21, T_longterm=20, T_sim=10^6, T_discard_sim=10^3, Bgrid_lb=1e-2, Bgrid_ub=2.5,
        σ=2., η=3., r=0.00598, ρ=0.9293, σ_ϵ=0.0115, θ=0.282, h=0.37,
        β=.83, β_hh=.99, α_m=1e-5, d0=-0.4, d1=0.43, λ=0.0465, κ=0., 
        ρ_B=1e-3, ρ_μ=1e-3, ρ_δ=1e-3
    )

    return ModelParams(
        nB, ny, T_longterm, T_sim, T_discard_sim, Bgrid_lb, Bgrid_ub,
        σ, η, r, ρ, σ_ϵ, θ, h, 
        β, β_hh, α_m, d0, d1, λ, κ, 
        ρ_B, ρ_μ, ρ_δ
    )
end

# Model Arrays
struct ModelArrays{V,A}
    Bgrid::V
    ygrid::V
    P::A
    
    v0::A
    v::A
    ev::A
    evd::A
    def_policy::A

    vr::A
    c_rep::A
    rb_rep::A
    Bprime_rep::A
    μ_rep::A
    i_rep::A
    q_rep::A
    qtilde_rep::A
    moneyEulerRHS_rep::A
    bondsEulerRHS_rep::A

    vd::A
    c_def::A
    rb_def::A
    Bprime_def::A
    μ_def::A
    i_def::A
    q_def::A
    qtilde_def::A
    moneyEulerRHS_def::A
    bondsEulerRHS_def::A
end
function build_ModelArrays(mp::ModelParams)
    # Bond grid
    Bgrid = collect(range(mp.Bgrid_lb, stop=mp.Bgrid_ub, length=mp.nB))
    Bgrid = CuArray(Bgrid)

    # Endowment grid and transition probs
    grid, P = tauchen_carlo(mp.ny, mp.ρ, mp.σ_ϵ)
    ygrid = CuArray(exp.(grid))
    P = CuArray(P)
    
    v0, v, ev, evd, def_policy = [CUDA.zeros(mp.nB, mp.ny) for i in 1:5]
    vr, c_rep, rb_rep, Bprime_rep, μ_rep, i_rep, q_rep, qtilde_rep, moneyEulerRHS_rep, bondsEulerRHS_rep = [CUDA.zeros(mp.nB, mp.ny) for i in 1:10]
    vd, c_def, rb_def, Bprime_def, μ_def, i_def, q_def, qtilde_def, moneyEulerRHS_def, bondsEulerRHS_def = [CUDA.zeros(mp.nB, mp.ny) for i in 1:10]

    return ModelArrays(
        Bgrid, ygrid, P,
        v0, v, ev, evd, def_policy,
        vr, c_rep, rb_rep, Bprime_rep, μ_rep, i_rep, q_rep, qtilde_rep, moneyEulerRHS_rep, bondsEulerRHS_rep,
        vd, c_def, rb_def, Bprime_def, μ_def, i_def, q_def, qtilde_def, moneyEulerRHS_def, bondsEulerRHS_def
    )
end
function Adapt.adapt_structure(to, model::ModelArrays)
    Bgrid = Adapt.adapt_structure(to, model.Bgrid)
    ygrid = Adapt.adapt_structure(to, model.ygrid)
    P = Adapt.adapt_structure(to, model.P)
    v0 = Adapt.adapt_structure(to, model.v0)
    v = Adapt.adapt_structure(to, model.v)
    ev = Adapt.adapt_structure(to, model.ev)
    evd = Adapt.adapt_structure(to, model.evd)
    def_policy = Adapt.adapt_structure(to, model.def_policy)
    vr = Adapt.adapt_structure(to, model.vr)
    c_rep = Adapt.adapt_structure(to, model.c_rep)
    rb_rep = Adapt.adapt_structure(to, model.rb_rep)
    Bprime_rep = Adapt.adapt_structure(to, model.Bprime_rep)
    μ_rep = Adapt.adapt_structure(to, model.μ_rep)
    i_rep = Adapt.adapt_structure(to, model.i_rep)
    q_rep = Adapt.adapt_structure(to, model.q_rep)
    qtilde_rep = Adapt.adapt_structure(to, model.qtilde_rep)
    moneyEulerRHS_rep = Adapt.adapt_structure(to, model.moneyEulerRHS_rep)
    bondsEulerRHS_rep = Adapt.adapt_structure(to, model.bondsEulerRHS_rep)
    vd = Adapt.adapt_structure(to, model.vd)
    c_def = Adapt.adapt_structure(to, model.c_def)
    rb_def = Adapt.adapt_structure(to, model.rb_def)
    Bprime_def = Adapt.adapt_structure(to, model.Bprime_def)
    μ_def = Adapt.adapt_structure(to, model.μ_def)
    i_def = Adapt.adapt_structure(to, model.i_def)
    q_def = Adapt.adapt_structure(to, model.q_def)
    qtilde_def = Adapt.adapt_structure(to, model.qtilde_def)
    moneyEulerRHS_def = Adapt.adapt_structure(to, model.moneyEulerRHS_def)
    bondsEulerRHS_def = Adapt.adapt_structure(to, model.bondsEulerRHS_def)

    ModelArrays(
        Bgrid, ygrid, P,
        v0, v, ev, evd, def_policy,
        vr, c_rep, rb_rep, Bprime_rep, μ_rep, i_rep, q_rep, qtilde_rep, moneyEulerRHS_rep, bondsEulerRHS_rep,
        vd, c_def, rb_def, Bprime_def, μ_def, i_def, q_def, qtilde_def, moneyEulerRHS_def, bondsEulerRHS_def,
    )
end

# Model Arrays (temporary)
struct ModelArraysTemp{A}
    vs_rep::A
    cs_rep::A
    rbs_rep::A
    cps_rep::A
    vs_def::A
    cps_def::A
end
function build_ModelArraysTemp(mp::ModelParams)
    vs_rep, cs_rep, rbs_rep, cps_rep, vs_def, cps_def = [CUDA.zeros(mp.nB, mp.ny, mp.nB) for i in 1:6]

    return ModelArraysTemp(
        vs_rep, cs_rep, rbs_rep, cps_rep, vs_def, cps_def
    )
end
function Adapt.adapt_structure(to, model::ModelArraysTemp)
    vs_rep = Adapt.adapt_structure(to, model.vs_rep)
    cs_rep = Adapt.adapt_structure(to, model.cs_rep)
    rbs_rep = Adapt.adapt_structure(to, model.rbs_rep)
    cps_rep = Adapt.adapt_structure(to, model.cps_rep)
    vs_def = Adapt.adapt_structure(to, model.vs_def)
    cps_def = Adapt.adapt_structure(to, model.cps_def)

    ModelArraysTemp(
        vs_rep, cs_rep, rbs_rep, cps_rep, vs_def, cps_def
    )
end

# Equilibrium Prices
struct PricesEqm{A}
    expdef_short_eqm_rep::A
    expdef_long_eqm_rep::A
    expinf_short_eqm_rep::A
    expinf_long_eqm_rep::A
    expinf_long_eqm_def::A
end
function build_PricesEqm(mp::ModelParams)
    expdef_short_eqm_rep, expdef_long_eqm_rep = [CUDA.zeros(Float32, mp.nB, mp.ny) for i in 1:2]
    expinf_short_eqm_rep, expinf_long_eqm_rep, expinf_long_eqm_def = [CUDA.ones(Float32, mp.nB, mp.ny) for i in 1:3]

    return PricesEqm(
        expdef_short_eqm_rep, expdef_long_eqm_rep, expinf_short_eqm_rep, expinf_long_eqm_rep, expinf_long_eqm_def
    )
end
function Adapt.adapt_structure(to, model::PricesEqm)
    expdef_short_eqm_rep = Adapt.adapt_structure(to, model.expdef_short_eqm_rep)
    expdef_long_eqm_rep = Adapt.adapt_structure(to, model.expdef_long_eqm_rep)
    expinf_short_eqm_rep = Adapt.adapt_structure(to, model.expinf_short_eqm_rep)
    expinf_long_eqm_rep = Adapt.adapt_structure(to, model.expinf_long_eqm_rep)
    expinf_long_eqm_def = Adapt.adapt_structure(to, model.expinf_long_eqm_def)

    PricesEqm(
        expdef_short_eqm_rep, expdef_long_eqm_rep, expinf_short_eqm_rep, expinf_long_eqm_rep, expinf_long_eqm_def
    )
end

# Future Prices
struct PricesFuture{A}
    expdef_short_future_rep::A
    expdef_long_future_rep::A
    expinf_short_future_rep::A
    expinf_long_future_rep::A
    expinf_long_future_def::A
end
function build_PricesFuture(mp::ModelParams)
    expdef_short_future_rep, expdef_long_future_rep, expinf_short_future_rep, expinf_long_future_rep, expinf_long_future_def = [CUDA.zeros(Float32, mp.nB, mp.ny) for i in 1:5]

    return PricesFuture(
        expdef_short_future_rep, expdef_long_future_rep, expinf_short_future_rep, expinf_long_future_rep, expinf_long_future_def
    )
end
function Adapt.adapt_structure(to, model::PricesFuture)
    expdef_short_future_rep = Adapt.adapt_structure(to, model.expdef_short_future_rep)
    expdef_long_future_rep = Adapt.adapt_structure(to, model.expdef_long_future_rep)
    expinf_short_future_rep = Adapt.adapt_structure(to, model.expinf_short_future_rep)
    expinf_long_future_rep = Adapt.adapt_structure(to, model.expinf_long_future_rep)
    expinf_long_future_def = Adapt.adapt_structure(to, model.expinf_long_future_def)

    PricesFuture(
        expdef_short_future_rep, expdef_long_future_rep, expinf_short_future_rep, expinf_long_future_rep, expinf_long_future_def
    )
end

# Simulation Arrays
struct SimulationArrays{Vfloat, Vbool, Vint}
    y_sim::Vfloat
    B_sim::Vfloat
    q_sim::Vfloat
    rb_sim::Vfloat
    μ_qoq_sim::Vfloat
    μ_yoy_sim::Vfloat
    def_status::Vbool
    def_new::Vbool
    inf_qoq_sim::Vfloat
    inf_yoy_sim::Vfloat
    c_sim::Vfloat
    i_sim::Vfloat
    B_sim_indices::Vint
    y_sim_indices::Vint
    taste_errors::Vfloat
end
function build_SimulationArrays(mp::ModelParams)
    y_sim, B_sim, q_sim, rb_sim, μ_qoq_sim, inf_qoq_sim, c_sim, i_sim = [zeros(Float32, mp.T_sim) for i in 1:8]
    μ_yoy_sim, inf_yoy_sim = [ones(Float32, mp.T_sim) for i in 1:8]
    def_status, def_new = [zeros(Bool, mp.T_sim) for i in 1:2]
    B_sim_indices, y_sim_indices = [zeros(Int32, mp.T_sim) for i in 1:2]
    taste_errors = zeros(Float32, 3)

    return SimulationArrays(
        y_sim, B_sim, q_sim, rb_sim, μ_qoq_sim, μ_yoy_sim, def_status, def_new, inf_qoq_sim, inf_yoy_sim, c_sim, i_sim, B_sim_indices, y_sim_indices, taste_errors
    )
end
function Adapt.adapt_structure(to, model::SimulationArrays)
    y_sim = Adapt.adapt_structure(to, model.y_sim)
    B_sim = Adapt.adapt_structure(to, model.B_sim)
    q_sim = Adapt.adapt_structure(to, model.q_sim)
    rb_sim = Adapt.adapt_structure(to, model.rb_sim)
    μ_qoq_sim = Adapt.adapt_structure(to, model.μ_qoq_sim)
    μ_yoy_sim = Adapt.adapt_structure(to, model.μ_yoy_sim)
    def_status = Adapt.adapt_structure(to, model.def_status)
    def_new = Adapt.adapt_structure(to, model.def_new)
    inf_qoq_sim = Adapt.adapt_structure(to, model.inf_qoq_sim)
    inf_yoy_sim = Adapt.adapt_structure(to, model.inf_yoy_sim)
    c_sim = Adapt.adapt_structure(to, model.c_sim)
    i_sim = Adapt.adapt_structure(to, model.i_sim)
    B_sim_indices = Adapt.adapt_structure(to, model.B_sim_indices)
    y_sim_indices = Adapt.adapt_structure(to, model.y_sim_indices)
    taste_errors = Adapt.adapt_structure(to, model.taste_errors)

    SimulationArrays(
        y_sim, B_sim, q_sim, rb_sim, μ_qoq_sim, μ_yoy_sim, def_status, def_new, inf_qoq_sim, inf_yoy_sim, c_sim, i_sim, B_sim_indices, y_sim_indices, taste_errors
    )
end

# Simulation Prices
struct SimulationPrices{V}
    expdef_short_sim::V
    expdef_long_sim::V
    expinf_short_sim::V
    expinf_long_sim::V
end
function build_SimulationPrices(mp::ModelParams)
    expdef_short_sim, expdef_long_sim, expinf_short_sim, expinf_long_sim = [zeros(Float32, mp.T_sim) for i in 1:4]

    return SimulationPrices(
        expdef_short_sim, expdef_long_sim, expinf_short_sim, expinf_long_sim
    )
end
function Adapt.adapt_structure(to, model::SimulationPrices)
    expdef_short_sim = Adapt.adapt_structure(to, model.expdef_short_sim)
    expdef_long_sim = Adapt.adapt_structure(to, model.expdef_long_sim)
    expinf_short_sim = Adapt.adapt_structure(to, model.expinf_short_sim)
    expinf_long_sim = Adapt.adapt_structure(to, model.expinf_long_sim)

    SimulationPrices(
        expdef_short_sim, expdef_long_sim, expinf_short_sim, expinf_long_sim
    )
end

# Functions
function tauchen_carlo(N::Int32, ρ::Float32, σ_ϵ::Float32; μ::Real=0, n_std::Real=4)

    # process (x_t above) standard deviation (std is ϵ's standard deviation)
    σ_y = σ_ϵ/sqrt(1-ρ^2)
    grid_bar = n_std * σ_y      # grid bounds
    grid = collect(Float32, range(μ-grid_bar, stop=μ+grid_bar, length=N))
    dif = grid[2]-grid[1]
  
    # Get transition probabilities
    P = zeros(Float32, N, N)
    
    # return nothing

    for row in 1:N
        
        # do endpoints first
        P[row, 1] = cdf(Normal(0., 1.), (grid[1]+dif/2 -(1-ρ)*μ -ρ*grid[row])/σ_ϵ )
        P[row, N] = 1-cdf(Normal(0., 1.), (grid[N]-dif/2 -(1-ρ)*μ -ρ*grid[row])/σ_ϵ )

        # middle columns
        for col in 2:N-1
            P[row, col] = cdf(Normal(0., 1.), (grid[col]+dif/2 -(1-ρ)*μ -ρ*grid[row])/σ_ϵ ) - cdf(Normal(0., 1.), (grid[col]-dif/2 -(1-ρ)*μ -ρ*grid[row])/σ_ϵ )
        end
    end

    # normalize
    sums = sum(P, dims=2)    

    P = @. P/sums
    
    if maximum(abs.(sum(P, dims=2).-1)) > 1e-6
        error("Matrix rows must sum up to 1!")
    end
  
    return grid, P
end

function ydef_fn(mp::ModelParams, y::Float32)
    return y - max(0, mp.d0*y + mp.d1*y^2)
end

function my_dot_product(xvec, yvec)
    temp = Float32(0)
    for i in 1:lastindex(xvec)
        temp += xvec[i]*yvec[i]
    end
    return temp
end

function my_brent(
    f::Function , x_lower::Float32, x_upper::Float32;
    rel_tol::Float32 = sqrt(eps(Float32)),
    abs_tol::Float32 = eps(Float32),
    iterations::Int32 = Int32(1000),
    my_trace::Bool = false)


    if x_lower > x_upper
        error("x_lower must be less than x_upper")
    end

    golden_ratio = Float32(1)/2 * (3 - sqrt(Float32(5.0)))

    new_minimizer = x_lower + golden_ratio*(x_upper-x_lower)
    new_minimum = f(new_minimizer)
    best_bound = "initial"
    f_calls = 1 # Number of calls to f
    step = zero(Float32)
    old_step = zero(Float32)

    old_minimizer = new_minimizer
    old_old_minimizer = new_minimizer

    old_minimum = new_minimum
    old_old_minimum = new_minimum

    iteration = 0
    converged = false
    stopped_by_callback = false

    while iteration < iterations && !stopped_by_callback

        p = zero(Float32)
        q = zero(Float32)

        x_tol = rel_tol * abs(new_minimizer) + abs_tol

        x_midpoint = (x_upper+x_lower)/2

        if abs(new_minimizer - x_midpoint) <= 2*x_tol - (x_upper-x_lower)/2
            converged = true
            break
        end

        iteration += 1

        if abs(old_step) > x_tol
            # Compute parabola interpolation
            # new_minimizer + p/q is the optimum of the parabola
            # Also, q is guaranteed to be positive

            r = (new_minimizer - old_minimizer) * (new_minimum - old_old_minimum)
            q = (new_minimizer - old_old_minimizer) * (new_minimum - old_minimum)
            p = (new_minimizer - old_old_minimizer) * q - (new_minimizer - old_minimizer) * r
            q = 2(q - r)

            if q > 0
                p = -p
            else
                q = -q
            end
        end

        if abs(p) < abs(q*old_step/2) && p < q*(x_upper-new_minimizer) && p < q*(new_minimizer-x_lower)
            old_step = step
            step = p/q

            # The function must not be evaluated too close to x_upper or x_lower
            x_temp = new_minimizer + step
            if ((x_temp - x_lower) < 2*x_tol || (x_upper - x_temp) < 2*x_tol)
                step = (new_minimizer < x_midpoint) ? x_tol : -x_tol
            end
        else
            old_step = (new_minimizer < x_midpoint) ? x_upper - new_minimizer : x_lower - new_minimizer
            step = golden_ratio * old_step
        end

        # The function must not be evaluated too close to new_minimizer
        if abs(step) >= x_tol
            new_x = new_minimizer + step
        else
            new_x = new_minimizer + ((step > 0) ? x_tol : -x_tol)
        end

        new_f = f(new_x)
        f_calls += 1

        if new_f < new_minimum
            if new_x < new_minimizer
                x_upper = new_minimizer
                best_bound = "upper"
            else
                x_lower = new_minimizer
                best_bound = "lower"
            end
            old_old_minimizer = old_minimizer
            old_old_minimum = old_minimum
            old_minimizer = new_minimizer
            old_minimum = new_minimum
            new_minimizer = new_x
            new_minimum = new_f
        else
            if new_x < new_minimizer
                x_lower = new_x
            else
                x_upper = new_x
            end
            if new_f <= old_minimum || old_minimizer == new_minimizer
                old_old_minimizer = old_minimizer
                old_old_minimum = old_minimum
                old_minimizer = new_x
                old_minimum = new_f
            elseif new_f <= old_old_minimum || old_old_minimizer == new_minimizer || old_old_minimizer == old_minimizer
                old_old_minimizer = new_x
                old_old_minimum = new_f
            end
        end
    end

    if my_trace
        out = iteration, iteration == iterations, converged, rel_tol, abs_tol, f_calls
        return new_minimizer, new_minimum, out
    else
        return new_minimizer, new_minimum
    end
end

function model_init!(mp::ModelParams, ma::ModelArrays)


    B0 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y
    # tid_x, tid_y, bid_x, bid_y = threadIdx().x, threadIdx().y, blockIdx().x, blockIdx().y
    # @cuprintln("y0 $y0, B0 $B0, tid_x $tid_x, tid_y $tid_y, bid_x $bid_x, bid_y $bid_y")

    if B0 <= mp.nB && y0 <= mp.ny
        #= Repayment: in the last period, max U(c,rb,g) s.t. c=y-̃B*rb =#
        ma.rb_rep[B0,y0] = 0.5 * ma.ygrid[y0]/ma.Bgrid[B0]
        ma.c_rep[B0,y0] = ma.ygrid[y0]-ma.Bgrid[B0]*ma.rb_rep[B0,y0]
        ma.vr[B0,y0] = (ma.c_rep[B0,y0]^(1-mp.σ))/(1-mp.σ) + mp.α_m*(ma.rb_rep[B0,y0]^(1-mp.η))/(1-mp.η)
        ma.Bprime_rep[B0,y0] = 0.
        ma.q_rep[B0, y0] = 1.
        
        #= Default: in the last period, max U(c,rb,g) s.t. c=y_def-̃B*(1-h)*rb =#
        yd = ydef_fn(mp, ma.ygrid[y0])
        ma.rb_def[B0,y0] = 0.5*yd/(ma.Bgrid[B0]*(1-mp.h))
        ma.c_def[B0,y0] = yd-ma.Bgrid[B0]*(1-mp.h)*ma.rb_def[B0,y0]
        ma.vd[B0,y0] = (ma.c_def[B0,y0]^(1-mp.σ))/(1-mp.σ) + mp.α_m*(ma.rb_def[B0,y0]^(1-mp.η))/(1-mp.η)
        # vd[B0,y0] = U_fn(m, c_def[B0,y0], rb_def[B0,y0])
        ma.Bprime_def[B0,y0] = 0.
        ma.μ_def[B0,y0] = 0.
        ma.q_def[B0, y0] = 1.
    end

    return nothing
end

function update_values_expectations_1!(mp::ModelParams, ma::ModelArrays)
    """
        update_values_expectations_1!()
        uses: m, vr, vd
        updates: def_policy, v
    """

    B0 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y

    if B0 <= mp.nB && y0 <= mp.ny

        # tid_x, tid_y, bid_x, bid_y = threadIdx().x, threadIdx().y, blockIdx().x, blockIdx().y
        # @cuprintln("y0 $y0, B0 $B0, B1_def_hc $B1_def_hc, tid_x $tid_x, tid_y $tid_y, bid_x $bid_x, bid_y $bid_y")

        if exp((ma.vd[B0,y0]-ma.vr[B0,y0])/mp.ρ_δ) == Inf
            ma.def_policy[B0,y0] = 1.
        else
            ma.def_policy[B0,y0] = exp((ma.vd[B0,y0]-ma.vr[B0,y0])/mp.ρ_δ) / (1+exp((ma.vd[B0,y0]-ma.vr[B0,y0])/mp.ρ_δ))
        end    
        ma.v[B0,y0] = ma.def_policy[B0,y0]*ma.vd[B0,y0] + (1-ma.def_policy[B0,y0])*ma.vr[B0,y0]
    end

    return nothing
end

function update_values_expectations_2!(mp::ModelParams, ma::ModelArrays)

    """
        update_values_expectations_2!()
        uses: m, Bgrid, v, vd, P, def_policy, c_rep, rb_rep, q_rep, c_def, rb_def, q_def
        updates: ev, evd, qtilde_rep, qtilde_def, moneyEulerRHS_rep, moneyEulerRHS_def, bondsEulerRHS_rep, bondsEulerRHS_def
    """

    B0 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y

    if B0 <= mp.nB && y0 <= mp.ny

        B1 = B0
        B1_def = B1     # to keep things clearer when computing qtilde_def
        B1_def_hc = CUDA.min(CUDA.searchsortedfirst(ma.Bgrid, ma.Bgrid[B1_def]*(1-mp.h)), mp.nB)

        # Reset values to zero
        ma.ev[B1, y0], ma.evd[B1, y0] = 0., 0.
        ma.qtilde_rep[B1, y0], ma.qtilde_def[B1, y0] = 0., 0.
        ma.moneyEulerRHS_rep[B1, y0], ma.moneyEulerRHS_def[B1, y0] = 0., 0.
        ma.bondsEulerRHS_rep[B1, y0], ma.bondsEulerRHS_def[B1, y0] = 0., 0.

        for y1 in 1:mp.ny

            # compute expected value functions, makes them functions of (̃B',y)
            ma.ev[B1, y0] += ma.v[B1, y1] * ma.P[y0, y1]
            ma.evd[B1, y0] += ma.vd[B1, y1] * ma.P[y0, y1]

            #= 
            the update of the qtilde price fns should only use q_rep and q_def, not qtilde's 
            =#

            # uses: def_policy, q_rep, rb_rep, q_def, rb_def
            ma.qtilde_rep[B1,y0] += (
                (1-ma.def_policy[B1,y1])*(mp.λ+(1-mp.λ)*(mp.κ+ma.q_rep[B1,y1]))*ma.rb_rep[B1,y1] + ma.def_policy[B1,y1]*ma.q_def[B1,y1]*ma.rb_def[B1,y1]
            ) * ma.P[y0,y1]
        
            # uses: q_def, rb_def here, q_rep, rb_rep below
            ma.qtilde_def[B1_def, y0] += (
                (1-mp.θ)*ma.q_def[B1_def,y1]*ma.rb_def[B1_def,y1] + 
                mp.θ*(
                    (1-ma.def_policy[B1_def_hc,y1])*(mp.λ+(1-mp.λ)*(mp.κ+ma.q_rep[B1_def_hc,y1]))*ma.rb_rep[B1_def_hc,y1] 
                    + ma.def_policy[B1_def_hc,y1]*ma.q_def[B1_def_hc,y1]*ma.rb_def[B1_def_hc,y1]
                )
            ) * ma.P[y0,y1]

            # uses: def_policy, c_rep, rb_rep, c_def, rb_def
            ma.moneyEulerRHS_rep[B1, y0] += mp.β_hh * (
                    (1-ma.def_policy[B1,y1])*(ma.c_rep[B1,y1]^(-mp.σ) + mp.α_m*ma.rb_rep[B1,y1]^(-mp.η))*ma.rb_rep[B1,y1] + ma.def_policy[B1,y1]*(ma.c_def[B1,y1]^(-mp.σ) + mp.α_m*ma.rb_def[B1,y1]^(-mp.η))*ma.rb_def[B1,y1]
                ) * ma.P[y0,y1]

            # uses: def_policy, c_rep, rb_rep, c_def, rb_def
            ma.moneyEulerRHS_def[B1, y0] += mp.β_hh * (
                    (1-mp.θ)*(ma.c_def[B1,y1]^(-mp.σ) + mp.α_m*ma.rb_def[B1,y1]^(-mp.η))*ma.rb_def[B1,y1] + 
                    mp.θ*(1-ma.def_policy[B1_def_hc,y1])*(ma.c_rep[B1_def_hc,y1]^(-mp.σ) + mp.α_m*ma.rb_rep[B1_def_hc,y1]^(-mp.η))*ma.rb_rep[B1_def_hc,y1] + 
                    mp.θ*ma.def_policy[B1_def_hc,y1]*(ma.c_def[B1_def_hc,y1]^(-mp.σ) + mp.α_m*ma.rb_def[B1_def_hc,y1]^(-mp.η))*ma.rb_def[B1_def_hc,y1]
                ) * ma.P[y0,y1]

            # uses: def_policy, c_rep, rb_rep, c_def, rb_def
            ma.bondsEulerRHS_rep[B1, y0] += mp.β_hh * (
                    (1-ma.def_policy[B1,y1])*(ma.c_rep[B1,y1]^(-mp.σ))*ma.rb_rep[B1,y1] + 
                    ma.def_policy[B1,y1]*(ma.c_def[B1,y1]^(-mp.σ))*ma.rb_def[B1,y1]
                ) * ma.P[y0,y1]

            # uses: def_policy, c_rep, rb_rep, c_def, rb_def
            ma.bondsEulerRHS_def[B1, y0] += mp.β_hh * (
                    (1-mp.θ)*(ma.c_def[B1,y1]^(-mp.σ))*ma.rb_def[B1,y1] + 
                    mp.θ*(1-ma.def_policy[B1_def_hc,y1])*(ma.c_rep[B1_def_hc,y1]^(-mp.σ))*ma.rb_rep[B1_def_hc,y1] + 
                    mp.θ*ma.def_policy[B1_def_hc,y1]*(ma.c_def[B1_def_hc,y1]^(-mp.σ))*ma.rb_def[B1_def_hc,y1]
                ) * ma.P[y0,y1]
        end
    end

    return nothing
end

function vr_gridsearch(mp::ModelParams, ma::ModelArrays, mat::ModelArraysTemp)
    
    B0 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y

    if B0 <= mp.nB && y0 <= mp.ny

        #y0s[B0,y0]=y0
        #B0s[B0,y0]=B0
        vstar = Float32(-Inf)

        for B1 in 1:mp.nB
            c_lb = Float32(1e-4)
            c_ub = ma.ygrid[y0] + ma.qtilde_rep[B1, y0]*ma.Bgrid[B1]

            c, ~ = my_brent(
                        c -> -(c^(1-mp.σ))/(1-mp.σ) - mp.α_m*((
                            (ma.ygrid[y0]+ma.qtilde_rep[B1,y0]*ma.Bgrid[B1]-c)/(ma.Bgrid[B0]*(mp.λ+(1-mp.λ)*mp.κ + ma.qtilde_rep[B1,y0]*(1-mp.λ)*c^(-mp.σ)/(mp.β_hh*ma.moneyEulerRHS_rep[B1, y0])))
                       )^(1-mp.η))/(1-mp.η), 
                        c_lb, c_ub)
            rb = (ma.ygrid[y0]+ma.qtilde_rep[B1,y0]*ma.Bgrid[B1]-c)/(ma.Bgrid[B0]*(mp.λ+(1-mp.λ)*mp.κ + ma.qtilde_rep[B1,y0]*(1-mp.λ)*c^(-mp.σ)/(mp.β_hh*ma.moneyEulerRHS_rep[B1, y0])))

            mat.cs_rep[B0,y0,B1] = c
            mat.rbs_rep[B0,y0,B1] = rb

            # ucprime = c^(-mp.σ)
            # μ = moneyEulerRHS_rep[B1,y0] / (rb * ucprime) - 1
            # μs_rep[B0,y0,B1] = μ
            # qs_rep[B0,y0,B1] = qtilde_rep[B1, y0] / (rb*(1+μ)*(1+mp.r))
            # is_rep[B0,y0,B1] = ((1+μ)*rb*ucprime) / bondsEulerRHS_rep[B1, y0]

            v = (c^(1-mp.σ))/(1-mp.σ) + mp.α_m*(rb^(1-mp.η))/(1-mp.η) + mp.β * ma.ev[B1, y0]
            mat.vs_rep[B0,y0,B1] = v
            vstar = ifelse(v>vstar, v, vstar)
        end
        
        D = 0.
        for B1 in 1:mp.nB
            D += exp((mat.vs_rep[B0,y0,B1]-vstar)/mp.ρ_B)
        end
        for B1 in 1:mp.nB
            mat.cps_rep[B0,y0,B1] = exp((mat.vs_rep[B0,y0,B1]-vstar)/mp.ρ_B)/D
        end
        
        ma.vr[B0,y0] = vstar + mp.ρ_B*log(D)

        ma.c_rep[B0,y0], ma.rb_rep[B0,y0], ma.Bprime_rep[B0,y0], ma.q_rep[B0,y0], ma.i_rep[B0,y0], ma.μ_rep[B0,y0] = 0., 0., 0., 0., 0., 0.
        for B1 in 1:mp.nB
            cp = mat.cps_rep[B0,y0,B1]
            
            c = mat.cs_rep[B0,y0,B1]
            rb = mat.rbs_rep[B0,y0,B1]
            ucprime = c^(-mp.σ)
            μ = ma.moneyEulerRHS_rep[B1,y0] / (rb * ucprime) - 1
            
            ma.c_rep[B0,y0] += cp * c
            ma.rb_rep[B0,y0] += cp * rb
            ma.q_rep[B0,y0] += cp * ma.qtilde_rep[B1, y0] / (rb*(1+μ)*(1+mp.r))
            
            # all of these things are not necessary for VFI and so can be computed only at the end
            ma.Bprime_rep[B0,y0] += cp * ma.Bgrid[B1]
            ma.i_rep[B0,y0] += cp * (((1+μ)*rb*ucprime) / ma.bondsEulerRHS_rep[B1, y0] -1)
            ma.μ_rep[B0,y0] += cp * μ
        end
    end

    return nothing
end

function vd_gridsearch(mp::ModelParams, ma::ModelArrays, mat::ModelArraysTemp)
    
    B0 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y
    
    if B0 <= mp.nB && y0 <= mp.ny

        #y0s[B0,y0]=y0
        #B0s[B0,y0]=B0
        vstar = Float32(-Inf)

        for B1_def in 1:mp.nB
            
            c = ydef_fn(mp, ma.ygrid[y0])
            μ = ma.Bgrid[B0]/ma.Bgrid[B1_def]-1
            ucprime = c^(-mp.σ)
            rb = ma.moneyEulerRHS_def[B1_def, y0] / (ucprime * (1+μ))
            B1_def_hc = min(searchsortedfirst(ma.Bgrid, ma.Bgrid[B1_def]*(1-mp.h)), mp.nB)
            
            #cs_def[B0,y0,B1_def] = c
            #μs_def[B0,y0,B1_def] = μ
            #rbs_def[B0,y0,B1_def] = rb
            #qs_def[B0,y0,B1_def] = qtilde_def[B1_def, y0] / (rb*(1+μ)*(1+mp.r))
            #is_def[B0,y0,B1_def] = ((1+μ)*rb*ucprime) / bondsEulerRHS_def[B1_def, y0]

            v = (c^(1-mp.σ))/(1-mp.σ) + mp.α_m*(rb^(1-mp.η))/(1-mp.η) + mp.β * (
                    (1-mp.θ)*ma.evd[B1_def, y0] + mp.θ*ma.ev[B1_def_hc, y0]
                )
            mat.vs_def[B0,y0,B1_def] = v

            vstar = ifelse(v>vstar, v, vstar)
        end
  
        D = 0.
        for B1_def in 1:mp.nB
            D += exp((mat.vs_def[B0,y0,B1_def]-vstar)/mp.ρ_μ)
        end
        for B1_def in 1:mp.nB
            mat.cps_def[B0,y0,B1_def] = exp((mat.vs_def[B0,y0,B1_def]-vstar)/mp.ρ_μ) / D
        end
        
        ma.vd[B0,y0] = vstar + mp.ρ_μ*log(D)
        ma.c_def[B0,y0] = ydef_fn(mp, ma.ygrid[y0])

        ma.rb_def[B0,y0], ma.Bprime_def[B0,y0], ma.q_def[B0,y0], ma.i_def[B0,y0], ma.μ_def[B0,y0] = 0., 0., 0., 0., 0.
        
        for B1_def in 1:mp.nB
            cp = mat.cps_def[B0,y0,B1_def]
            
            μ = ma.Bgrid[B0]/ma.Bgrid[B1_def]-1
            ucprime = ma.c_def[B0,y0]^(-mp.σ)
            rb = ma.moneyEulerRHS_def[B1_def, y0] / (ucprime*(1+μ))
            

            ma.μ_def[B0,y0] += cp * μ
            ma.rb_def[B0,y0] += cp * rb
            ma.Bprime_def[B0,y0] += cp * ma.Bgrid[B1_def]
            ma.q_def[B0,y0] += cp * ma.qtilde_def[B1_def, y0] / (rb*(1+μ)*(1+mp.r))
            ma.i_def[B0,y0] += cp * (((1+μ)*rb*ucprime) / ma.bondsEulerRHS_def[B1_def, y0] -1)
            
        end
    end

    return nothing
end

function compute_prices_future!(mp::ModelParams, ma::ModelArrays, pe::PricesEqm, pf::PricesFuture)
    """
        compute_prices_future!()
        uses: 
        - P, def_policy, rb_rep, rb_def
        - expdef_long_eqm_rep, expinf_long_eqm_rep, expinf_long_eqm_def
        updates: 
        - expdef_short_future_rep, expdef_long_future_rep, expinf_short_future_rep, expinf_long_future_rep
    """
    # Uses eqm prices to compute future prices (that depends on (B',y))
    
    # Perform computations
    B1 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y

    if B1 <= mp.nB && y0 <= mp.ny
        B1_def = B1     # to keep things clearer when computing qtilde_def
        B1_def_hc = CUDA.min(CUDA.searchsortedfirst(ma.Bgrid, ma.Bgrid[B1_def]*(1-mp.h)), mp.nB)

        pf.expdef_short_future_rep[B1,y0], pf.expdef_long_future_rep[B1,y0], pf.expinf_short_future_rep[B1,y0], pf.expinf_long_future_rep[B1,y0], pf.expinf_long_future_def[B1_def,y0] = 0., 0., 0., 0., 0.
        
        for y1 in 1:mp.ny
            pf.expdef_short_future_rep[B1,y0] += (
                ma.def_policy[B1,y1]
            ) * ma.P[y0,y1]
            
            pf.expdef_long_future_rep[B1,y0] += (
                ma.def_policy[B1,y1] + (1-ma.def_policy[B1,y1])*pe.expdef_long_eqm_rep[B1,y1]
            ) * ma.P[y0,y1]
            
            # E[ 1/m_t+1(B_t+1, y_t+1) | y_t ]      GROSS inflation!!!
            pf.expinf_short_future_rep[B1,y0] += (
                (1-ma.def_policy[B1,y1]) * 1/ma.rb_rep[B1,y1] + ma.def_policy[B1,y1] * 1/ma.rb_def[B1,y1]
            ) * ma.P[y0,y1]
            
            # E[ XCS^eqm_t+1(B_t+1, y_t+1) / m_t+1(B_t+1, y_t+1) | y_t ]    GROSS inflation!!!
            pf.expinf_long_future_rep[B1,y0] += (
                (1-ma.def_policy[B1,y1]) * pe.expinf_long_eqm_rep[B1,y1]/ma.rb_rep[B1,y1] + ma.def_policy[B1,y1] * pe.expinf_long_eqm_def[B1,y1]/ma.rb_def[B1,y1]
            ) * ma.P[y0,y1]

            pf.expinf_long_future_def[B1_def,y0] += (
                (1-mp.θ) * pe.expinf_long_eqm_def[B1_def,y1]/ma.rb_def[B1_def,y1]
                + mp.θ*(1-ma.def_policy[B1_def_hc,y1]) * pe.expinf_long_eqm_rep[B1_def_hc,y1]/ma.rb_rep[B1_def_hc,y1] 
                + mp.θ*ma.def_policy[B1_def_hc,y1] * pe.expinf_long_eqm_def[B1_def_hc,y1]/ma.rb_def[B1_def_hc,y1]
            ) * ma.P[y0,y1]
        end
    end
    return nothing
end

function compute_prices_eqm!(mp::ModelParams, ma::ModelArrays, mat::ModelArraysTemp, pe::PricesEqm, pf::PricesFuture)
    """
        compute_prices_eqm!()
        uses: 
        - def_policy, cps_rep, rbs_rep, cs_rep, cps_def
        - expdef_short_future_rep, expdef_long_future_rep, expinf_short_future_rep, expinf_long_future_rep, expinf_long_future_def
        updates: 
        - expdef_short_eqm_rep, expdef_long_eqm_rep, expinf_short_eqm_rep, expinf_long_eqm_rep, expinf_long_eqm_def
    """

    # Perform computations
    B0 = (blockIdx().x-1)*blockDim().x + threadIdx().x
    y0 = (blockIdx().y-1)*blockDim().y + threadIdx().y
    
    if B0 <= mp.nB && y0 <= mp.ny
        c_def = ydef_fn(mp, ma.ygrid[y0])

        pe.expdef_short_eqm_rep[B0,y0], pe.expdef_long_eqm_rep[B0,y0], pe.expinf_short_eqm_rep[B0,y0], pe.expinf_long_eqm_rep[B0,y0], pe.expinf_long_eqm_def[B0,y0] = 0., 0., 0., 0., 0.
        
        for B1 in 1:mp.nB

            pe.expdef_short_eqm_rep[B0,y0] += mat.cps_rep[B0,y0,B1] * pf.expdef_short_future_rep[B1,y0]
            pe.expdef_long_eqm_rep[B0,y0] += mat.cps_rep[B0,y0,B1] * pf.expdef_long_future_rep[B1,y0]
                
            rb_rep = mat.rbs_rep[B0,y0,B1]
            c_rep = mat.cs_rep[B0,y0,B1]
            μ_rep = ma.moneyEulerRHS_rep[B1,y0] / (rb_rep * (c_rep^(-mp.σ))) - 1
            
            pe.expinf_short_eqm_rep[B0,y0] += mat.cps_rep[B0,y0,B1] * rb_rep * (1+μ_rep) * pf.expinf_short_future_rep[B1,y0]
            pe.expinf_long_eqm_rep[B0,y0] += mat.cps_rep[B0,y0,B1] * rb_rep * (1+μ_rep) * pf.expinf_long_future_rep[B1,y0]

            B1_def = B1
            μ_def = ma.Bgrid[B0]/ma.Bgrid[B1_def]-1
            rb_def = ma.moneyEulerRHS_def[B1_def, y0] / (c_def^(-mp.σ) * (1+μ_def))

            pe.expinf_long_eqm_def[B0,y0] += mat.cps_def[B0,y0,B1_def] * rb_def * (1+μ_def) * pf.expinf_long_future_def[B1_def,y0]
        end
    end
    return nothing
end

function main_gpu(mp::ModelParams; max_iter::Int=1000, print_iter::Int=0, plot::Int=0, ret_arrays::Bool=false, sim_print::String="no")

    # Define GPU threads and blocks
    threadsize = 16
    ts = (threadsize, threadsize)
    blocksize = cld(mp.nB, threadsize)
    bs = (blocksize, blocksize)

    # Create ModelArrays object
    ma = build_ModelArrays(mp)
    mat = build_ModelArraysTemp(mp)

    # Initialise everything
    @cuda threads=ts blocks=bs model_init!(mp, ma)    
    @cuda threads=ts blocks=bs update_values_expectations_1!(mp, ma)
    @cuda threads=ts blocks=bs update_values_expectations_2!(mp, ma)

    # Iterative process
    err = 1e5
    tol = 1e-5
    iter = 0
    
    while (err > tol) & (iter < max_iter)
        
        iter += 1
        err = 0.
        ma.v0 .= ma.v
        #q0_rep .= q_rep
        #err_qrep = 0.
        #Vd0 = deepcopy(Vd)
        #Price0 = deepcopy(Price)
        # println(vd)
        
        @cuda threads=ts blocks=bs vr_gridsearch(mp, ma, mat)
        @cuda threads=ts blocks=bs vd_gridsearch(mp, ma, mat)
        @cuda threads=ts blocks=bs update_values_expectations_1!(mp, ma)
        @cuda threads=ts blocks=bs update_values_expectations_2!(mp, ma)

        err = maximum(@. abs(ma.v-ma.v0))

        if print_iter > 0
            if rem(iter, print_iter) == 0
                println(@sprintf("iter %.0f, error %.2e", iter, err))
            end
        end
    end
    println(@sprintf("vfi ends with %.0f iters, error %.2e", iter, err))


    #= Compute the eqm objects and asset prices which were not needed for VFI but are needed for the simulations =#
    pe = build_PricesEqm(mp)
    pf = build_PricesFuture(mp)
    
    for i in 1:mp.T_longterm
        @cuda threads=ts blocks=bs compute_prices_future!(mp, ma, pe, pf)       # use eqm to compute future
        @cuda threads=ts blocks=bs compute_prices_eqm!(mp, ma, mat, pe, pf)     # use future to compute eqm
        #show(IOContext(stdout, :limit=>false), "text/plain", expdef_long_future_rep)
    end
    
    #show(IOContext(stdout, :limit=>false), "text/plain", [expdef_short_eqm_rep expdef_long_future_rep])

    # Simulation: allocate and Pre-Fill
    sa = build_SimulationArrays(mp)
    sp = build_SimulationPrices(mp)

    if sim_print != "no"
        simulate_cg!(mp, ma, mat, pf, sa, sp)   # Simulate the economy

        if sim_print == "table"         # Print moments table
            sim_mom!(mp, sa, sp, print_flag=sim_print)

        elseif sim_print == "moments"   # Compute a few moments for calibration purposes
            out = sim_mom!(mp, sa, sp, print_flag=sim_print)
            return out
        end
    end

    if plot>0
        plot_eqm(mp, ma, fn=plot)
    end
    
    if ret_arrays
        return m, grids, arrays, arrays_rep, arrays_def, arrays_temp_rep, arrays_temp_def
    else
        return nothing
    end
end

#= 
SIMULATIONS
=#
function markov_draw!(grid::Vector{Float32}, P::Array{Float32}, out_vector::Vector, T::Int32; ret_indices::Bool=false, init_index::Int=round(Int, length(grid)/2), RNG::MersenneTwister=MersenneTwister())
    #=
    Generate a sample path of a Markov chain, from a given initial state. The resulting vector, of dimension T (number of simulation periods), has the state values of the Markov chain as elements.
    Uses: P (the discrete Markov transition matrix), grid (the state grid)
    =#
    Q = cumsum(P, dims=2)   # CDF, for each state
    simulated_indices = zeros(Int32, T)
    simulated_indices[1] = init_index
    randdraws = rand(RNG, T)
    for i in 2:T
        i_prev = simulated_indices[i-1]
        simulated_indices[i] = searchsortedfirst(view(Q,i_prev,:), randdraws[i-1])
    end

    if ret_indices
        out_vector .= simulated_indices
    else
        out_vector .= grid[simulated_indices]
    end
    
    return nothing
end

function formatfn(v, row, col)
    if isa(v, String)
        return v
    else
        if abs(v) < 10^5 && abs(v) >= 1e-2
            return @sprintf("%.2f", v)
        else
            return @sprintf("%.1e", v)
        end
    end
end

function simulate_cg!(
        mp::ModelParams, ma::ModelArrays, mat::ModelArraysTemp, pf::PricesFuture, sa::SimulationArrays, sp::SimulationPrices; y_init=1., B_init=1.
    )

    #=
    REMEMBER TO DON'T COUNT DEFAULT PERIODS WHEN COMPUTING SPREADS !!!!
    =#

    Bgrid = convert(Array, ma.Bgrid)
    ygrid = convert(Array, ma.ygrid)
    P = convert(Array, ma.P)

    def_policy = convert(Array, ma.def_policy)
    # v    # ev    # evd
    vr = convert(Array, ma.vr)
    # c_rep    # rb_rep    # Bprime_rep    # μ_rep    # i_rep    # q_rep
    qtilde_rep = convert(Array, ma.qtilde_rep)
    moneyEulerRHS_rep = convert(Array, ma.moneyEulerRHS_rep)
    bondsEulerRHS_rep = convert(Array, ma.bondsEulerRHS_rep)

    vd = convert(Array, ma.vd)
    c_def = convert(Array, ma.c_def)
    # rb_def    # Bprime_def    # μ_def    # i_def    # q_def
    qtilde_def = convert(Array, ma.qtilde_def)
    moneyEulerRHS_def = convert(Array, ma.moneyEulerRHS_def)
    bondsEulerRHS_def = convert(Array, ma.bondsEulerRHS_def)

    vs_rep = convert(Array, mat.vs_rep)
    cs_rep = convert(Array, mat.cs_rep)
    rbs_rep = convert(Array, mat.rbs_rep)
    cps_rep = convert(Array, mat.cps_rep)
    vs_def = convert(Array, mat.vs_def)
    cps_def = convert(Array, mat.cps_def)

    expdef_short_future_rep = convert(Array, pf.expdef_short_future_rep)
    expdef_long_future_rep = convert(Array, pf.expdef_long_future_rep)
    expinf_short_future_rep = convert(Array, pf.expinf_short_future_rep)
    expinf_long_future_rep = convert(Array, pf.expinf_long_future_rep)
    expinf_long_future_def = convert(Array, pf.expinf_long_future_def)
    # expdef_short_eqm_rep, expdef_long_eqm_rep, expinf_short_eqm_rep, expinf_long_eqm_rep, expinf_long_eqm_def = convert(NTuple{5, Array}, prices_eqm)

    cps_cum_rep = Array{Float32}(accumulate(+, mat.cps_rep, dims=3))
    cps_cum_def = Array{Float32}(accumulate(+, mat.cps_def, dims=3))

    # Get initial indices
    y_init_index = searchsortedfirst(ygrid, y_init)
    B_init_index = searchsortedfirst(Bgrid, B_init)

    # Create a MarkovChain
    MT = MersenneTwister(6687)
    markov_draw!(ygrid, P, sa.y_sim_indices, mp.T_sim, ret_indices=true, init_index=y_init_index, RNG=MT)  

    # Get taste shocks for both [B'] and [μ']
    tasteshocks = rand(MT, mp.T_sim)

    # Get default shocks
    defshocks = rand(MT, mp.T_sim)

    # Get re-entry shocks    
    reentryshocks = rand(MT, mp.T_sim)

    # Compute expected value of taste shock "errors", i.e. the average (over iB,iy) expected % utility loss, which is =dot(choiceprobs, log(vs/vstar))
    taste_error_B = mean([my_dot_product(cps_rep[iB,iy,:], log.(vs_rep[iB,iy,:]./maximum(vs_rep[iB,iy,:]))) for iB in 1:mp.nB, iy in 1:mp.ny])
    taste_error_μ = mean([my_dot_product(cps_def[iB,iy,:], log.(vs_def[iB,iy,:]./maximum(vs_def[iB,iy,:]))) for iB in 1:mp.nB, iy in 1:mp.ny])
    taste_error_δ = mean([log(vd[iB,iy]/max(vr[iB,iy],vd[iB,iy]))+1/(1+exp((vd[iB,iy]-vr[iB,iy])/mp.ρ_δ))*log(vr[iB,iy]/vd[iB,iy]) for iB in 1:mp.nB, iy in 1:mp.ny])
    sa.taste_errors .= [taste_error_B; taste_error_μ; taste_error_δ]
    #sa.taste_errors .= [0.; 0.; 0.]

    sa.B_sim_indices[1] = B_init_index
    sa.def_status[1] = false 

    # Time simulation
    for t=1:mp.T_sim-1

        # Get indices of current period
        iyt, iBt = sa.y_sim_indices[t], sa.B_sim_indices[t]
        sa.y_sim[t] = ygrid[iyt]
        sa.B_sim[t] = Bgrid[iBt]
        #show t, iBt, iyt
        #show B_sim

        #=
        [1] If you are NOT in default *from the past*
        =#
        if sa.def_status[t] == false

            # check if you want to default today
            # default_today = mp.vr[iBt, iyt] < mp.vd[iBt, iyt]
            default_today = defshocks[t] < def_policy[iBt,iyt]

            # [1a] If you DO want to default today
            if default_today
                sa.def_new[t] = true

            # [1b] If you do NOT default
            else
                iBtnext_rep = searchsortedfirst(view(cps_cum_rep,iBt,iyt,:), tasteshocks[t])
                
                sa.B_sim_indices[t+1] = iBtnext_rep

                sa.c_sim[t] = cs_rep[iBt,iyt,iBtnext_rep]
                ucprime_rep = sa.c_sim[t]^(-mp.σ)
                sa.rb_sim[t] = rbs_rep[iBt,iyt,iBtnext_rep]
                sa.μ_qoq_sim[t] = moneyEulerRHS_rep[iBtnext_rep,iyt] / (sa.rb_sim[t] * ucprime_rep) - 1
                sa.q_sim[t] = qtilde_rep[iBtnext_rep, iyt] / (sa.rb_sim[t]*(1+sa.μ_qoq_sim[t])*(1+mp.r))
                sa.i_sim[t] = ( (1+sa.μ_qoq_sim[t])*sa.rb_sim[t]*ucprime_rep ) / bondsEulerRHS_rep[iBtnext_rep, iyt] - 1
                
                sp.expdef_short_sim[t] = expdef_short_future_rep[iBtnext_rep, iyt]
                sp.expdef_long_sim[t] = expdef_long_future_rep[iBtnext_rep, iyt]
                sp.expinf_short_sim[t] = expinf_short_future_rep[iBtnext_rep, iyt] * sa.rb_sim[t]*(1+sa.μ_qoq_sim[t]) - 1
                sp.expinf_long_sim[t] = expinf_long_future_rep[iBtnext_rep, iyt] * sa.rb_sim[t]*(1+sa.μ_qoq_sim[t]) - 1

                if t==1
                    # normalise M/P=1 at t=0
                    sa.inf_qoq_sim[t] = 0.
                else
                    sa.inf_qoq_sim[t] = sa.rb_sim[t-1]*(1+sa.μ_qoq_sim[t-1])/sa.rb_sim[t]-1
                end
                if t<4
                    sa.inf_yoy_sim[t] = 0.
                    sa.μ_yoy_sim[t] = 0.
                else
                    #sa.inf_yoy_sim[t] = prod(1 .+ sa.inf_qoq_sim[t-3:t])-1
                    #sa.μ_yoy_sim[t] = prod(1 .+ sa.μ_qoq_sim[t-3:t])-1
                    for j in 0:3
                        sa.inf_yoy_sim[t] *= 1+sa.inf_qoq_sim[t-j]
                        sa.μ_yoy_sim[t] *= 1+sa.μ_qoq_sim[t-j]
                    end
                    sa.inf_yoy_sim[t] -= 1.
                    sa.μ_yoy_sim[t] -= 1.
                end
            end
        end
        # need to close the if and open another one for the change in def_status[t] to be picked up

        #=
        [2] If you are in default 
            - either from the past (=> did not get settlement option)
            - or from the present (=> just defaulted)
        =#
        if sa.def_status[t] == true || sa.def_new[t] == true

            sa.y_sim[t] = ydef_fn(mp, ygrid[iyt])     # replaces y_sim[t]

            # index corresponding to B'=B/(1+μ) tomorrow
            #iB1d = searchsortedfirst(cps_cum_def[iBt,iyt,:], tasteshocks[t])
            iB1d = searchsortedfirst(view(cps_cum_def,iBt,iyt,:), tasteshocks[t])
            B1d = Bgrid[iB1d]

            # wrongchoice_ind[t] = iB1d != findmax(choiceprobs_def[iBt,iyt])[2]

            sa.μ_qoq_sim[t] = Bgrid[iBt]/Bgrid[iB1d]-1
            sa.c_sim[t] = c_def[iBt,iyt]
            sa.rb_sim[t] = moneyEulerRHS_def[iB1d,iyt] / ( (sa.c_sim[t]^(-mp.σ)) * (1+sa.μ_qoq_sim[t]) )
            sa.q_sim[t] = qtilde_def[iB1d, iyt] / (sa.rb_sim[t]*(1+sa.μ_qoq_sim[t])*(1+mp.r))
            sa.i_sim[t] = ( (1+sa.μ_qoq_sim[t])*sa.rb_sim[t] * (sa.c_sim[t]^(-mp.σ)) ) / bondsEulerRHS_def[iB1d,iyt] -1

            if t==1
                sa.inf_qoq_sim[t] = 0.
            else
                sa.inf_qoq_sim[t] = sa.rb_sim[t-1]*(1+sa.μ_qoq_sim[t-1])/sa.rb_sim[t]-1
            end
            if t<4
                sa.inf_yoy_sim[t] = 0.
                sa.μ_yoy_sim[t] = 0.
            else
                #sa.inf_yoy_sim[t] = prod(1 .+ sa.inf_qoq_sim[t-3:t])-1
                #sa.μ_yoy_sim[t] = prod(1 .+ sa.μ_qoq_sim[t-3:t])-1
                for j in 0:3
                    sa.inf_yoy_sim[t] *= 1+sa.inf_qoq_sim[t-j]
                    sa.μ_yoy_sim[t] *= 1+sa.μ_qoq_sim[t-j]
                end
                sa.inf_yoy_sim[t] -= 1.
                sa.μ_yoy_sim[t] -= 1.
            end


            # actual future B' depends on θ
            if reentryshocks[t] < mp.θ && sa.def_new[t] == false
                # with prob θ get settlement option tomorrow, when not after a fresh default
                sa.def_status[t+1] = false

                # B_sim_indices[t+1] = min(searchsortedfirst(mp.Bgrid, mp.Bgrid[iBt]*(1-mp.h)/(1+μ_qoq_sim[t])), mp.nB)
                sa.B_sim_indices[t+1] = min(searchsortedfirst(Bgrid, B1d*(1-mp.h)), mp.nB)
                # debt carried over to face settlement choice tomorrow

            else    # with prob 1-θ no settlement option tomorrow
                sa.def_status[t+1] = true

                # B_sim_indices[t+1] = min(searchsortedfirst(mp.Bgrid, mp.Bgrid[iBt]/(1+μ_qoq_sim[t])), mp.nB)
                sa.B_sim_indices[t+1] = iB1d
            end
        end
    end

    return nothing
end

function sim_mom!(mp::ModelParams, sa::SimulationArrays, sp::SimulationPrices;
        fignum::Int=0, print_flag::String="table"
    )

    # Convert SimulationArrays
    y_sim = CuArray(sa.y_sim[mp.T_discard_sim:end-1])
    B_sim = CuArray(sa.B_sim[mp.T_discard_sim:end-1])
    q_sim = CuArray(sa.q_sim[mp.T_discard_sim:end-1])
    rb_sim = CuArray(sa.rb_sim[mp.T_discard_sim:end-1])
    μ_qoq_sim = CuArray(sa.μ_qoq_sim[mp.T_discard_sim:end-1])
    μ_yoy_sim = CuArray(sa.μ_yoy_sim[mp.T_discard_sim:end-1])
    def_status = CuArray(sa.def_status[mp.T_discard_sim:end-1])
    def_new = CuArray(sa.def_new)[mp.T_discard_sim:end-1]
    inf_qoq_sim = CuArray(sa.inf_qoq_sim[mp.T_discard_sim:end-1])
    inf_yoy_sim = CuArray(sa.inf_yoy_sim[mp.T_discard_sim:end-1])
    c_sim = CuArray(sa.c_sim[mp.T_discard_sim:end-1])
    i_sim = CuArray(sa.i_sim[mp.T_discard_sim:end-1])
    q_sim = CuArray(sa.q_sim[mp.T_discard_sim:end-1])
    B_sim_indices = CuArray(sa.B_sim_indices[mp.T_discard_sim:end-1])
    y_sim_indices = CuArray(sa.y_sim_indices[mp.T_discard_sim:end-1])
    taste_error_B, taste_error_μ, taste_error_δ = [sa.taste_errors[i] for i in 1:3]

    # Convert SimulationPrices
    expdef_short_sim = CuArray(sp.expdef_short_sim[mp.T_discard_sim:end-1])
    expdef_long_sim = CuArray(sp.expdef_long_sim[mp.T_discard_sim:end-1])
    expinf_short_sim = CuArray(sp.expinf_short_sim[mp.T_discard_sim:end-1])
    expinf_long_sim = CuArray(sp.expinf_long_sim[mp.T_discard_sim:end-1])

    T = length(y_sim)
    
    # Compute repay and default indicators (of length T_sim-T_discard)
    repind = @. def_status==false && def_new==false     # indicates with 1 periods with access to markets, i.e. where u enter with good credit standing AND you stay in markets by repaying
    defind = @. repind==false
    T_rep = sum(repind)

    # Compute full-simulation repayment and default indicators (of length T_sim)
    def_status_long = CuArray(sa.def_status[1:end-1])
    def_new_long = CuArray(sa.def_new)[1:end-1]
    repind_long = @. def_status_long==false && def_new_long==false

    # Compute year-long default and repayment indicators
    repind_yoy = @. repind_long[mp.T_discard_sim:end] * repind_long[mp.T_discard_sim-1:end-1] * repind_long[mp.T_discard_sim-2:end-2] * repind_long[mp.T_discard_sim-3:end-3]
    defind_yoy = @. repind_long[mp.T_discard_sim:end] + repind_long[mp.T_discard_sim-1:end-1] + repind_long[mp.T_discard_sim-2:end-2] + repind_long[mp.T_discard_sim-3:end-3] == 0
    # if repind_yoy[t]=1, then the govt has NEVER defaulted or been in default between t-4 and t
    # if defind_yoy[t]=1, then the govt has ALWAYS been in default between t-4 and t

    # Show that these 3 sets of events indeed include all possibilities
    #residual_yoy = @. 0 < (repind_long[mp.T_discard_sim:end] + repind_long[mp.T_discard_sim-1:end-1] + repind_long[mp.T_discard_sim-2:end-2] + repind_long[mp.T_discard_sim-3:end-3]) < 4
    #show sum(repind_yoy)+sum(defind_yoy)+sum(residual_yoy), T

    # Create repay and default series
    y_rep = y_sim[repind]
    y_def = y_sim[defind]
    B_rep = B_sim[repind]
    B_def = B_sim[defind]
    rb_rep = rb_sim[repind]
    c_rep = c_sim[repind]
    c_def = c_sim[defind]
    q_rep = q_sim[repind]
    q_def = q_sim[defind]
    expdef_short_rep = expdef_short_sim[repind]
    expdef_long_rep = expdef_long_sim[repind]
    expinf_short_rep = expinf_short_sim[repind]
    expinf_long_rep = expinf_long_sim[repind]
    
    inf_qoq_rep = inf_qoq_sim[repind]
    inf_qoq_def = inf_qoq_sim[defind]
    μ_qoq_rep = μ_qoq_sim[repind]
    μ_qoq_def = μ_qoq_sim[defind]

    inf_yoy_rep = inf_yoy_sim[repind_yoy]
    inf_yoy_def = inf_yoy_sim[defind_yoy]
    μ_yoy_rep = μ_yoy_sim[repind_yoy]
    μ_yoy_def = μ_yoy_sim[defind_yoy]

    i_rep = i_sim[repind]
    i_def = i_sim[defind]


    # Compute moments of macro variables
    sd_y_rep = std(y_rep)
    mean_mbasegdp = mean(rb_rep./y_rep); sd_mbasegdp = std(rb_rep./y_rep)
    mean_debtmoney_rep = mean(B_rep); sd_debtmoney_rep = std(B_rep)
    mean_debtmoney_def = mean(B_def); sd_debtmoney_def = std(B_def)
    debtgdp_rep = @. B_rep*rb_rep/y_rep
    mean_debtgdp = mean(debtgdp_rep); sd_debtgdp = std(debtgdp_rep)
    b_rep = B_rep.*rb_rep; sd_b_rep = std(B_rep.*rb_rep)
    mean_consgdp_rep = mean(c_rep./y_rep); sd_consgdp_rep = std(c_rep./y_rep)
    mean_consgdp_def = mean(c_def./y_def); sd_consgdp_def = std(c_def./y_def)

    mean_cpi_rep = mean(inf_yoy_rep); sd_cpi_rep = std(inf_yoy_rep)
    mean_cpi_def = mean(inf_yoy_def); sd_cpi_def = std(inf_yoy_def)
    mean_cpi_qoq_rep = mean(inf_qoq_rep); sd_cpi_qoq_rep = std(inf_qoq_rep)
    mean_cpi_qoq_def = mean(inf_qoq_def); sd_cpi_qoq_def = std(inf_qoq_def)
    mean_mu_rep = mean(μ_yoy_rep); sd_mu_rep = std(μ_yoy_rep)
    mean_mu_def = mean(μ_yoy_def); sd_mu_def = std(μ_yoy_def)
    mean_seign_rep = mean(μ_yoy_rep.*rb_sim[repind_yoy]); sd_seign_rep = std(μ_yoy_rep.*rb_sim[repind_yoy])
    cv_seign_rep = mean_seign_rep/sd_seign_rep      # coefficient of variation

    # Compute annualised expected default and inflation
    mean_q_rep = mean(q_rep); sd_q_rep = std(q_rep)
    mean_q_def = mean(q_def); sd_q_def = std(q_def)

    #cds_short_rep = @. 1-(1-expdef_short_rep)^4; 
    #cds_long_rep = @. 1-(1-expdef_long_rep)^(1/(mp.T_longterm/4));
    cds_short_rep = expdef_short_rep
    cds_long_rep = expdef_long_rep
    mean_cds_short = mean(cds_short_rep); sd_cds_short = std(cds_short_rep)
    mean_cds_long = mean(cds_long_rep); sd_cds_long = std(cds_long_rep)
    
    #xcs_short_rep = @. ((1+expinf_short_rep)^4-1); 
    xcs_short_rep = expinf_short_rep
    xcs_long_rep = expinf_long_rep
    xcs_long_rep2 = @. (1+expinf_long_rep)^(1/(mp.T_longterm/4))-1
    mean_xcs_short = mean(xcs_short_rep); sd_xcs_short = std(xcs_short_rep)
    mean_xcs_long = mean(xcs_long_rep); sd_xcs_long = std(xcs_long_rep)
    sd_xcs_long2 = std(xcs_long_rep2)

    #i_annual_rep = @. ((1+i_rep)^4-1); mean_i_rep = mean(i_annual_rep); sd_i_rep = std(i_annual_rep)
    #i_annual_def = @. ((1+i_def)^4-1); mean_i_def = mean(i_annual_def); sd_i_def = std(i_annual_def)
    mean_i_qoq_rep = mean(i_rep); sd_i_qoq_rep = std(i_rep)
    mean_i_qoq_def = mean(i_def); sd_i_qoq_def = std(i_def)

    newdefault_freq_qtrly = sum(@. def_status==false && def_new==true)/sum(@. def_status==false)
    newdefault_freq_yrly = 1-(1-newdefault_freq_qtrly)^4
    indefault = sum(@. def_status==true)/T

    # Total spread (default + inflation). Follows Hatchondo and Martinez's (2009) calculations
    ytms = @. (mp.λ+(1-mp.λ)*mp.κ)/q_sim-mp.λ       # constant yield implied by bond prices
    spread = @. ((1+ytms)/(1+mp.r))^4-1          # annualised total spread
    spread_rep = spread[repind]
    mean_spread = mean(spread_rep); sd_spread = std(spread_rep)

    # Correlations
    rho_cds_xcs_short = cov(cds_short_rep, xcs_short_rep)/(sd_cds_short*sd_xcs_short)
    rho_cds_xcs_long = cov(cds_long_rep, xcs_long_rep)/(sd_cds_long*sd_xcs_long)
    rho_cds_xcs_long2 = cov(cds_long_rep, xcs_long_rep2)/(sd_cds_long*sd_xcs_long2)

    rho_y_cds = cov(y_rep, cds_long_rep)/(sd_y_rep*sd_cds_long)
    rho_y_xcs = cov(y_rep, xcs_long_rep)/(sd_y_rep*sd_xcs_long)
    rho_y_cpi = cov(y_rep, inf_qoq_rep)/(sd_y_rep*sd_cpi_rep)
    rho_y_b = cov(y_rep, b_rep)/(sd_y_rep*sd_b_rep)
    rho_y_spread = cov(y_rep, spread_rep)/(sd_y_rep*sd_spread)
    rho_debtgdp_spread = cov(debtgdp_rep, spread_rep)/(sd_debtgdp*sd_spread)
    rho_y_cpi = cov(y_rep, inf_qoq_rep)/(sd_y_rep*sd_cpi_rep)
    rho_b_cds = cov(b_rep, cds_long_rep)/(sd_b_rep*sd_cds_long)
    rho_b_xcs = cov(b_rep, xcs_long_rep)/(sd_b_rep*sd_xcs_long)
    rho_cds_cpi = cov(cds_long_rep, inf_qoq_rep)/(sd_cds_long*sd_cpi_rep)

    # Time spent on Bgrid bounds
    time_lb = sum(B_sim.==mp.Bgrid_lb)
    time_ub = sum(B_sim.==mp.Bgrid_ub)

    if print_flag == "moments"
        out = [
            mean_debtgdp*100, 
            mean_mbasegdp*100, 
            mean_cds_long*100, 
            sd_cds_long*100, 
            mean_cpi_rep*100,
            time_lb/T*100,
            time_ub/T*100
        ]
        return out
    end

    if print_flag == "table"
        # Bound behaviour    
        
        if time_ub>0 && time_lb>0
            # println("Bgrid: both bounds are binding")
            println(@sprintf("%% time on LB: %.2f, on UB: %.2f", time_lb/T, time_ub/T))
        elseif time_ub>0
            # println("Bgrid: upper bound is binding")
            println(@sprintf("%% time on UB: %.2f", time_ub/T))
        elseif time_lb>0
            # println("Bgrid: lower bound is binding")
            println(@sprintf("%% time on LB: %.2f", time_lb/T))
        end
        
        # Print out tables
        column_headers = ["statistic", "corr, mean", "stdev"]
        output = [
            "corr(cds, xcs) short"     rho_cds_xcs_short        "";
            "corr(cds, xcs) long"      rho_cds_xcs_long        "";
            "corr(cds, xcs) long2"     rho_cds_xcs_long2        "";
            "___"                      ""                 "";
            "corr(y, cds)"             rho_y_cds          "";
            "corr(y, xcs)"             rho_y_xcs          "";
            "corr(y, cpi)"             rho_y_cpi          "";
            "corr(cpi, cds)"           rho_cds_cpi        "";
            "corr(y, b)"               rho_y_b            "";
            "___"                      ""                 "";
            "taste error B/M"          taste_error_B      "";
            "taste error mu"           taste_error_μ      "";
            "taste error default"      taste_error_δ      "";
            "___"                      ""                 "";
            "b/y (%)"  mean_debtgdp*100   sd_debtgdp*100;
            "m/y (%)"  mean_mbasegdp*100  sd_mbasegdp*100;
            "B/M rep (%)"  mean_debtmoney_rep*100    sd_debtmoney_rep*100;
            "B/M def (%)"  mean_debtmoney_def*100    sd_debtmoney_def*100;
            "c/y rep (%)"   mean_consgdp_rep*100   sd_consgdp_rep*100;
            "c/y def (%)"   mean_consgdp_def*100   sd_consgdp_def*100;
            "___"                      ""                 "";
            "yearly default freq %" newdefault_freq_yrly*100 "";
            "yearly default periods %" indefault*100 "";
            "cds short (%), ann.ed" mean_cds_short*100 sd_cds_short*100;
            "cds long (%), ann.ed" mean_cds_long*100 sd_cds_long*100;
            "seign_rep (%), ann.ed" mean_seign_rep*100 sd_seign_rep*100;
            "q rep" mean_q_rep sd_q_rep;
            "q def" mean_q_def sd_q_def;
            "___"                      ""                 "";
            "yoy cpi rep (%)" mean_cpi_rep*100 sd_cpi_rep*100;
            "yoy cpi def (%)" mean_cpi_def*100 sd_cpi_def*100;
            "yoy mu rep (%)" mean_mu_rep*100 sd_mu_rep*100;
            "yoy mu def (%)" mean_mu_def*100 sd_mu_def*100;
            "___"                      ""                 "";
            "qoq cpi rep (%)" mean_cpi_qoq_rep*100 sd_cpi_qoq_rep*100;
            "qoq i rep (%)" mean_i_qoq_rep*100 sd_i_qoq_rep*100;
            "B/M rep (%)"  mean_debtmoney_rep*100    sd_debtmoney_rep*100;
            "qoq cpi def (%)" mean_cpi_qoq_def*100 sd_cpi_qoq_def*100;
            "qoq i def (%)" mean_i_qoq_def*100 sd_i_qoq_def*100;
            ]

        println(@sprintf("ny=%.0f, nB=%.0f, B∈[%.2f, %.2f], θ=%.2f, h=%.2f, ρ_B=%.1e, ρ_mu=%.1e, ρ_D=%.1e, β_hh=%.4f, r=%.4f, σ=%.0f, η=%.1f, λ=%.4f, κ=%.4f, β=%.2f, α_M=%.1e, d0=%.4f, d1=%.4f",
        mp.ny, mp.nB, mp.Bgrid_lb, mp.Bgrid_ub, mp.θ, mp.h,
        mp.ρ_B, mp.ρ_μ, mp.ρ_δ,
        mp.β_hh, mp.r, mp.σ, mp.η, 
        mp.λ, mp.κ, 
        mp.β, mp.α_m, mp.d0, mp.d1))

        pretty_table(output, header=column_headers, formatters=formatfn)

        if sum(cds_long_rep)<1e-6
            println("Default probs are always zero!")
        end
    end

    return
end
# Out:
# sim_mom! (generic function with 1 method)

# %%
#=
PLOTS
=#
function plot_eqm(mp::ModelParams, ma::ModelArrays; fn::Int=1)
    #CUDA.allowscalar(true)

    Bgrid = convert(Array, ma.Bgrid)
    ygrid = convert(Array, ma.ygrid)
    def_policy = convert(Array, ma.def_policy)
    vr = convert(Array, ma.vr)
    vd = convert(Array, ma.vd)
    rb_rep = convert(Array, ma.rb_rep)
    rb_def = convert(Array, ma.rb_def)
    c_rep = convert(Array, ma.c_rep)
    c_def = convert(Array, ma.c_def)
    Bprime_rep = convert(Array, ma.Bprime_rep)
    Bprime_def = convert(Array, ma.Bprime_def)
    μ_rep = convert(Array, ma.μ_rep)
    μ_def = convert(Array, ma.μ_def)
    q_rep = convert(Array, ma.q_rep)
    q_def = convert(Array, ma.q_def)

    figure(fn, figsize=(4,4), dpi=150)
    clf()
    rows = 3; cols = 3
    fig, axs = subplots(rows, cols, num=fn, clear=true)

    unc_stdev = mp.σ_ϵ/sqrt((1-mp.ρ^2))
    iys = [min(searchsortedfirst(ygrid, 1+unc_stdev*j), mp.ny) for j in -2:1:2]
    # iys = [5;10;15]

    for iy in iys

        sca(axs[1]); title(L"V(\tilde B,y)")
        l1,=plot(Bgrid, vr[:,iy], label=@sprintf("y = %.4f", ygrid[iy]))
        c=l1.get_color()
        plot(Bgrid, vd[:,iy], "--", color=c)
        xlabel(L"\tilde B")

        sca(axs[2]); title(L"m(\tilde B,y)")
        plot(Bgrid, rb_rep[:,iy], "-", color=c)
        plot(Bgrid, rb_def[:,iy], "--", color=c)
        xlabel(L"\tilde B")

        sca(axs[3]); title("Consumption")
        plot(Bgrid, c_rep[:,iy])
        plot(Bgrid, c_def[:,iy], "--", color=c)
        xlabel(L"\tilde B")

        sca(axs[4]); title(L"\tilde B'(\tilde B, y)")
        plot(Bgrid, Bprime_rep[:,iy], "-", color=c)
        plot(Bgrid, Bprime_def[:,iy], "--", color=c)
        plot(Bgrid, Bgrid, ":k")
        xlabel(L"\tilde B")
        
        sca(axs[5]); title(L"\mu(\tilde B, y)")
        plot(Bgrid, μ_rep[:,iy], "-", color=c)
        plot(Bgrid, μ_def[:,iy], "--", color=c)
        plot(Bgrid, zeros(mp.nB), ":k")
        xlabel(L"\tilde B")

        sca(axs[6]); title(L"\tilde B/(1+\mu')")
        plot(Bgrid, Bgrid./(1 .+μ_def[:,iy]), "--", color=c)
        plot(Bgrid, Bgrid, "--k")
        xlabel(L"\tilde B")

        sca(axs[7]); title("Eqm Debt Prices")
        plot(Bgrid, q_rep[:,iy], "-", color=c)
        plot(Bgrid, q_def[:,iy], "--", color=c)
        xlabel(L"\tilde B")

        sca(axs[8]); title("eqm default probs")
        plot(Bgrid, def_policy[:,iy], "-", color=c)
        xlabel(L"\tilde B")
    end

    fs_base = 6
    plot_style(fn, fs=fs_base, fs_legend=fs_base-2, fs_label=fs_base, format_tick_labels=false,
    yticklabsize=fs_base-2, xticklabsize=fs_base-2, tick_direction="out", tick_pad=2, 
    tick_width=0.5, tick_length=3, hl=2, legend_loc=0, xlabel_coords=(0.5, -0.05), ylabel_coords=(-0.05,0.5))
    subplots_adjust(left=0.05, right=0.95, top=0.94, bottom=0.06, wspace=0.3, hspace=0.3)
end

function plot_style(fignum; 
    fs::Real=10, 				# fontsize singlegraph
    fs_title::Real=NaN,   				# fontsize title (defaults to fs)
    fs_legend::Real=NaN, 				# fontsize legend (defaults to fs)
    fs_label::Real=NaN, 				# fontsize label (defaults to fs)
    xticklabsize::Real=NaN, 	
    yticklabsize::Real=NaN, 	
    xlabel_coords::Tuple=(0.5, -0.1),
    ylabel_coords::Tuple=(-0.1, 0.5),
    title_coords::Tuple=(0.5, 1.05),
    legend_labelspacing::Real=0,	# vertical space between legend labels
    legend_columnspacing::Real=2, 					# spacing between columns
    legend_handlepad::Real=1,				# space between legend handle and text
    legend_loc=0,						# legend location (0=best)
    hl::Real=1, 					# legend handlelength
    legend_ncol=1,
    ldir_subplot::String="in",
    xtick_label_format::String="%.2f",
    ytick_label_format::String="%.2f", 
    xtick_number=NaN,
    ytick_number=NaN, 
    format_tick_labels::Bool=false,
    tick_direction="in",
    tick_rotation=0,
    xtick_rotation=NaN,
    ytick_rotation=NaN,
    tick_pad=4,
    tick_width=1,
    tick_length=4
    )

    fig = Float64	
    if isa(fignum,PyPlot.Figure)
        fig = fignum
    elseif isa(fignum,Int)
        fig = figure(fignum)
    end
    axs = fig.axes
    fmt_x = matplotlib.ticker.FormatStrFormatter(xtick_label_format)
    fmt_y = matplotlib.ticker.FormatStrFormatter(ytick_label_format)

    if isnan(fs_legend); fs_legend=fs; end
    if isnan(fs_title); fs_title=fs; end
    if isnan(fs_label); fs_label=fs; end
    if isnan(xticklabsize); xticklabsize=fs-4; end
    if isnan(yticklabsize); yticklabsize=fs-4; end

    for i in 1:length(axs)
        ca = axs[i]
        
        ca.tick_params.("both", labelcolor = "k", direction = tick_direction, length = tick_length, width = tick_width, pad = tick_pad, colors = "k", rotation=tick_rotation)
        ca.tick_params.("x", labelsize = xticklabsize, rotation=(isnan(xtick_rotation) ? tick_rotation : xtick_rotation))
        ca.tick_params.("y", labelsize = yticklabsize, rotation=(isnan(ytick_rotation) ? tick_rotation : ytick_rotation))
        ca.xaxis.label.set_size(fs_label)
        ca.yaxis.label.set_size(fs_label)
        ca.xaxis.set_label_coords.(xlabel_coords[1], xlabel_coords[2])	    
        ca.yaxis.set_label_coords.(ylabel_coords[1], ylabel_coords[2])

        if format_tick_labels
            ca.xaxis.set_major_formatter(fmt_x)
            ca.yaxis.set_major_formatter(fmt_y)
        end
        
        if length(ca.get_title())>0 		# there is a title
            ca.title.set_size(fs_title)
            ca.title.set_y.(title_coords)
        end

        if isnan(xtick_number)==false
            xl, xh = ca.get_xlim()
            ca.xaxis.set_ticks(range(xl, stop=xh, length=xtick_number))
        end
        if isnan(ytick_number)==false
            yl, yh = ca.get_ylim()
            ca.yaxis.set_ticks(range(yl, stop=yh, length=ytick_number))
        end

        
        if isa(ca.get_legend_handles_labels()[2],Array{String})	# there is a legend			
            ca.legend(fontsize = fs_legend, handlelength = hl, frameon = false, labelspacing=legend_labelspacing, loc=legend_loc, ncol=legend_ncol, columnspacing=legend_columnspacing, handletextpad=legend_handlepad)
        end
    end
end
# Out:
# plot_style (generic function with 1 method)

# %% [markdown]
# # Execute code

# %%
@time main_gpu(build_ModelParams(nB=51, ny=21, T_longterm=20), max_iter=100, print_iter=5)

# %%
@time main_gpu(
    build_ModelParams(nB=51, ny=21, T_longterm=20, T_sim=10^6, T_discard_sim=100), 
    max_iter=100, print_iter=0, sim_print="table")

# %%
# These are the default parameters
@time main_gpu(
    build_ModelParams(
        nB=51, ny=21, T_longterm=20, T_sim=10^6, T_discard_sim=10^3, Bgrid_lb=1e-2, Bgrid_ub=2.5,
        σ=2., η=3., r=0.00598, ρ=0.9293, σ_ϵ=0.0115, θ=0.282, h=0.37,
        β=.83, β_hh=.99, α_m=1e-5, d0=-0.4, d1=0.43, λ=0.0465, κ=0., 
        ρ_B=1e-4, ρ_μ=1e-3, ρ_δ=1e-3
        ), 
    max_iter=100, print_iter=0, sim_print="table")

# %%
(1/.99)^4-1
# Out:
# 0.04102035568521689

# %% [markdown]
# # Calibration experiments
#
# Now we play around with the parameters.
#
# I re-arranged the params of the model to highlight those that we'll estimate to match our targets.

# %%
Pkg.add(["DataFrames", "CSV"])
using DataFrames, CSV
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`

# %%
# Proper test to see if we're writing on the CSV even if we stop halfway because of an error
function dftest(df1)
    n1 = size(df1)[1]
    for i in 1:n1
        df1[i,:] .= rand(3)
        CSV.write("newtest.csv", df1)
        if i>=11
            error("random error to interrupt the loop")
        end
    end
    return nothing
end

n=10
df = DataFrame(c1=zeros(n), c2=zeros(n), c3=zeros(n))
@time dftest(df)

# %%
# (THIS IS BETTER!)
# Another test to append rows iteratively
filename = "test.csv"
for i in 1:5
    df = DataFrame(c1=rand(), c2=rand(), c3=rand())
    CSV.write(filename, df, writeheader=(i==1), append=true)
end

# %%
function create_StackedParamVector(parvectuple)
    Narrays = length(parvectuple)
    Ns = [length(parvectuple[i]) for i in 1:Narrays]
    N = prod(Ns)
    spv = zeros(N, Narrays)

    for i in 1:Narrays
        if 1<i<Narrays
            spv[:,i] = repeat(kron(parvectuple[i], ones(prod(Ns[i+1:end]))), prod(Ns[1:i-1]))
        elseif i==1
            spv[:,i] = kron(parvectuple[i], ones(prod(Ns[i+1:end])))
        elseif i==Narrays
            spv[:,i] = repeat(parvectuple[i],prod(Ns[1:i-1]))
        end
    end

    return spv
end
# Out:
# 1800

# %%
function param_loop(filename)
    d0s = collect(Float32, 0.:0.1:0.5); nd0 = length(d0s)
    deltas = collect(Float32, 0.:0.01:0.04); ndelta = length(deltas)
    alphams = collect(Float32, range(1e-6, stop=1e-2, length=8)); nalpham = length(alphams)
    betas = collect(Float32, 0.7:0.05:0.9); nbeta = length(betas)
    lambdas = collect(Float32, 0.05:0.05:0.25); nlambda = length(lambdas)

    N = nd0*ndelta*nalpham*nbeta*nlambda
    println("total number of params is $N")
    
    iter = 0
    out = zeros(Float32, 7)

    for (id0, d0) in enumerate(d0s)
        for (idelta, delta) in enumerate(deltas)
            for (ialpham, alpham) in enumerate(alphams)
                for (ibeta, beta) in enumerate(betas)
                    for (ilambda, lambda) in enumerate(lambdas)
                    
                        iter += 1
                        @show iter
                        
                        out .= main_gpu(
                            build_ModelParams(
                                nB=51, ny=21, T_longterm=20, T_sim=10^6, T_discard_sim=10^3, Bgrid_lb=1e-2, Bgrid_ub=2.5,
                                σ=2., η=3., r=0.00598, ρ=0.9293, σ_ϵ=0.0115, θ=0.282, h=0.37, β_hh=.99, κ=0.,
                                β=beta, α_m=alpham, d0=-d0, d1=d0+delta, λ=lambda, 
                                ρ_B=1e-3, ρ_μ=1e-3, ρ_δ=1e-3
                            ), max_iter=300, print_iter=0, sim_print="moments")
                        
                        df = DataFrame(
                            mean_debtgdp=out[1], mean_mbasegdp=out[2], mean_cds_long=out[3],
                            sd_cds_long=out[4], sharetime_lb=out[5], sharetime_ub=out[6],
                            beta=beta, alpha_m=alpham, d_0=-d0, d_1=d0+delta, lambda=lambda
                        )
                        CSV.write(filename, df, writeheader=(iter==1), append=(iter>1))

                        #if iter >= 4; error("stop"); end
                    end
                end
            end
        end
    end

    return nothing
end
# Out:
# param_loop (generic function with 2 methods)

# %%
filename = "parloop_6000.csv"
param_loop(filename)
# Out:
# iter = 607
# vfi ends with 40 iters, error 8.58e-06
# iter = 608
# vfi ends with 40 iters, error 8.58e-06
# iter = 609
# vfi ends with 40 iters, error 8.58e-06
# iter = 610
# vfi ends with 40 iters, error 8.58e-06
# iter = 611
# vfi ends with 52 iters, error 8.11e-06
# iter = 612
# vfi ends with 52 iters, error 8.58e-06
# iter = 613
# vfi ends with 52 iters, error 8.58e-06
# iter = 614
# vfi ends with 52 iters, error 8.11e-06
# iter = 615
# vfi ends with 52 iters, error 8.58e-06
# iter = 616
# vfi ends with 71 iters, error 9.06e-06
# iter = 617
# vfi ends with 71 iters, error 9.06e-06
# iter = 618
# vfi ends with 71 iters, error 9.06e-06
# iter = 619
# vfi ends with 71 iters, error 9.06e-06
# iter = 620
# vfi ends with 71 iters, error 9.06e-06
# iter = 621
# vfi ends with 110 iters, error 9.54e-06
# iter = 622
# vfi ends with 110 iters, error 9.54e-06
# iter = 623
# vfi ends with 110 iters, error 9.54e-06
# iter = 624
# vfi ends with 110 iters, error 9.54e-06
# iter = 625
# vfi ends with 110 iters, error 9.54e-06
# iter = 626
# vfi ends with 34 iters, error 9.78e-06
# iter = 627
# vfi ends with 300 iters, error 4.69e-04
# iter = 628
# vfi ends with 300 iters, error 8.69e-04
# iter = 629
# vfi ends with 300 iters, error 8.34e-04
# iter = 630
# vfi ends with 300 iters, error 1.16e-03
# iter = 631
# vfi ends with 46 iters, error 6.20e-06
# iter = 632
# vfi ends with 300 iters, error 5.47e-04
# iter = 633
# vfi ends with 300 iters, error 1.19e-03
# iter = 634
# vfi ends with 300 iters, error 9.79e-04
# iter = 635
# vfi ends with 300 iters, error 1.29e-03
# iter = 636
# vfi ends with 72 iters, error 8.58e-06
# iter = 637
# vfi ends with 300 iters, error 4.22e-03
# iter = 638
# vfi ends with 300 iters, error 9.04e-04
# iter = 639
# vfi ends with 300 iters, error 8.67e-04
# iter = 640
# vfi ends with 300 iters, error 3.76e-04
# iter = 641
# vfi ends with 102 iters, error 9.06e-06
# iter = 642
# vfi ends with 300 iters, error 9.13e-03
# iter = 643
# vfi ends with 300 iters, error 8.12e-04
# iter = 644
# vfi ends with 300 iters, error 3.97e-04
# iter = 645
# vfi ends with 300 iters, error 3.12e-04
# iter = 646
# vfi ends with 120 iters, error 9.54e-06
# iter = 647
# vfi ends with 300 iters, error 9.54e-05
# iter = 648
# vfi ends with 300 iters, error 1.62e-04
# iter = 649
# vfi ends with 123 iters, error 8.58e-06
# iter = 650
# vfi ends with 114 iters, error 9.54e-06
# iter = 651
# vfi ends with 300 iters, error 5.83e-03
# iter = 652
# vfi ends with 300 iters, error 1.60e-03
# iter = 653
# vfi ends with 300 iters, error 2.06e-03
# iter = 654
# vfi ends with 300 iters, error 3.11e-03
# iter = 655
# vfi ends with 300 iters, error 2.37e-03
# iter = 656
# vfi ends with 300 iters, error 8.72e-03
# iter = 657
# vfi ends with 300 iters, error 1.41e-03
# iter = 658
# vfi ends with 300 iters, error 2.40e-03
# iter = 659
# vfi ends with 300 iters, error 3.56e-03
# iter = 660
# vfi ends with 300 iters, error 7.66e-03
# iter = 661
# vfi ends with 300 iters, error 6.45e-03
# iter = 662
# vfi ends with 300 iters, error 3.42e-03
# iter = 663
# vfi ends with 300 iters, error 5.12e-03
# iter = 664
# vfi ends with 300 iters, error 8.85e-03
# iter = 665
# vfi ends with 300 iters, error 5.40e-03
# iter = 666
# vfi ends with 300 iters, error 7.89e-03
# iter = 667
# vfi ends with 300 iters, error 9.54e-03
# iter = 668
# vfi ends with 207 iters, error 8.58e-06
# iter = 669
# vfi ends with 300 iters, error 3.03e-03
# iter = 670
# vfi ends with 300 iters, error 4.88e-03
# iter = 671
# vfi ends with 126 iters, error 8.58e-06
# iter = 672
# vfi ends with 300 iters, error 1.88e-04
# iter = 673
# vfi ends with 111 iters, error 9.54e-06
# iter = 674
# vfi ends with 115 iters, error 8.58e-06
# iter = 675
# vfi ends with 300 iters, error 4.20e-05
# iter = 676
# vfi ends with 300 iters, error 7.91e-03
# iter = 677
# vfi ends with 300 iters, error 3.27e-03
# iter = 678
# vfi ends with 300 iters, error 4.36e-03
# iter = 679
# vfi ends with 300 iters, error 4.02e-03
# iter = 680
# vfi ends with 300 iters, error 1.25e-02
# iter = 681
# vfi ends with 300 iters, error 7.33e-03
# iter = 682
# vfi ends with 300 iters, error 4.35e-03
# iter = 683
# vfi ends with 300 iters, error 5.29e-03
# iter = 684
# vfi ends with 300 iters, error 6.36e-03
# iter = 685
# vfi ends with 300 iters, error 1.08e-02
# iter = 686
# vfi ends with 300 iters, error 7.73e-03
# iter = 687
# vfi ends with 300 iters, error 5.05e-03
# iter = 688
# vfi ends with 300 iters, error 4.80e-03
# iter = 689
# vfi ends with 300 iters, error 7.81e-03
# iter = 690
# vfi ends with 300 iters, error 6.24e-03
# iter = 691
# vfi ends with 300 iters, error 9.42e-03
# iter = 692
# vfi ends with 300 iters, error 3.06e-03
# iter = 693
# vfi ends with 300 iters, error 4.43e-03
# iter = 694
# vfi ends with 300 iters, error 5.07e-03
# iter = 695
# vfi ends with 300 iters, error 5.60e-03
# iter = 696
# vfi ends with 300 iters, error 1.06e-02
# iter = 697
# vfi ends with 300 iters, error 4.46e-04
# iter = 698
# vfi ends with 117 iters, error 9.54e-06
# iter = 699
# vfi ends with 115 iters, error 9.54e-06
# iter = 700
# vfi ends with 117 iters, error 9.54e-06
# iter = 701
# vfi ends with 300 iters, error 5.13e-03
# iter = 702
# vfi ends with 300 iters, error 4.89e-03
# iter = 703
# vfi ends with 300 iters, error 5.94e-03
# iter = 704
# vfi ends with 300 iters, error 6.37e-03
# iter = 705
# vfi ends with 300 iters, error 1.62e-02
# iter = 706
# vfi ends with 300 iters, error 4.31e-03
# iter = 707
# vfi ends with 300 iters, error 8.92e-03
# iter = 708
# vfi ends with 300 iters, error 5.78e-03
# iter = 709
# vfi ends with 300 iters, error 1.09e-02
# iter = 710
# vfi ends with 300 iters, error 9.16e-03
# iter = 711
# vfi ends with 300 iters, error 5.28e-03
# iter = 712
# vfi ends with 300 iters, error 6.07e-03
# iter = 713
# vfi ends with 300 iters, error 8.38e-03
# iter = 714
# vfi ends with 300 iters, error 1.04e-02
# iter = 715
# vfi ends with 300 iters, error 6.72e-03
# iter = 716
# vfi ends with 300 iters, error 8.81e-03
# iter = 717
# vfi ends with 300 iters, error 3.81e-03
# iter = 718
# vfi ends with 300 iters, error 7.09e-03
# iter = 719
# vfi ends with 300 iters, error 6.19e-03
# iter = 720
# vfi ends with 300 iters, error 7.47e-03
# iter = 721
# vfi ends with 300 iters, error 1.51e-02
# iter = 722
# vfi ends with 300 iters, error 1.80e-03
# iter = 723
# vfi ends with 300 iters, error 1.82e-03
# iter = 724
# vfi ends with 167 iters, error 8.58e-06
# iter = 725
# vfi ends with 127 iters, error 9.54e-06
# iter = 726
# vfi ends with 300 iters, error 2.81e-03
# iter = 727
# vfi ends with 300 iters, error 4.98e-03
# iter = 728
# vfi ends with 300 iters, error 1.09e-02
# iter = 729
# vfi ends with 300 iters, error 9.48e-03
# iter = 730
# vfi ends with 300 iters, error 1.12e-02
# iter = 731
# vfi ends with 300 iters, error 2.49e-03
# iter = 732
# vfi ends with 300 iters, error 1.07e-02
# iter = 733
# vfi ends with 300 iters, error 6.40e-03
# iter = 734
# vfi ends with 300 iters, error 1.23e-02
# iter = 735
# vfi ends with 300 iters, error 1.05e-02
# iter = 736
# vfi ends with 300 iters, error 3.27e-03
# iter = 737
# vfi ends with 300 iters, error 6.08e-03
# iter = 738
# vfi ends with 300 iters, error 6.60e-03
# iter = 739
# vfi ends with 300 iters, error 1.07e-02
# iter = 740
# vfi ends with 300 iters, error 7.10e-03
# iter = 741
# vfi ends with 300 iters, error 1.03e-02
# iter = 742
# vfi ends with 300 iters, error 6.12e-03
# iter = 743
# vfi ends with 300 iters, error 8.41e-03
# iter = 744
# vfi ends with 300 iters, error 6.09e-03
# iter = 745
# vfi ends with 300 iters, error 8.21e-03
# iter = 746
# vfi ends with 300 iters, error 1.67e-02
# iter = 747
# vfi ends with 300 iters, error 3.43e-03
# iter = 748
# vfi ends with 300 iters, error 5.72e-05
# iter = 749
# vfi ends with 137 iters, error 8.58e-06
# iter = 750
# vfi ends with 300 iters, error 1.37e-03
# iter = 751
# vfi ends with 300 iters, error 3.52e-03
# iter = 752
# vfi ends with 300 iters, error 5.93e-03
# iter = 753
# vfi ends with 300 iters, error 1.01e-02
# iter = 754
# vfi ends with 300 iters, error 1.15e-02
# iter = 755
# vfi ends with 300 iters, error 1.58e-02
# iter = 756
# vfi ends with 300 iters, error 4.57e-03
# iter = 757
# vfi ends with 300 iters, error 6.26e-03
# iter = 758
# vfi ends with 300 iters, error 7.54e-03
# iter = 759
# vfi ends with 300 iters, error 9.26e-03
# iter = 760
# vfi ends with 300 iters, error 1.45e-02
# iter = 761
# vfi ends with 300 iters, error 5.67e-03
# iter = 762
# vfi ends with 300 iters, error 5.53e-03
# iter = 763
# vfi ends with 300 iters, error 6.36e-03
# iter = 764
# vfi ends with 300 iters, error 9.23e-03
# iter = 765
# vfi ends with 300 iters, error 8.30e-03
# iter = 766
# vfi ends with 300 iters, error 8.12e-03
# iter = 767
# vfi ends with 300 iters, error 6.79e-03
# iter = 768
# vfi ends with 300 iters, error 7.95e-03
# iter = 769
# vfi ends with 300 iters, error 9.97e-03
# iter = 770
# vfi ends with 300 iters, error 9.70e-03
# iter = 771
# vfi ends with 300 iters, error 1.74e-02
# iter = 772
# vfi ends with 300 iters, error 2.45e-03
# iter = 773
# vfi ends with 300 iters, error 4.96e-05
# iter = 774
# vfi ends with 300 iters, error 3.24e-03
# iter = 775
# vfi ends with 300 iters, error 9.51e-03
# iter = 776
# vfi ends with 300 iters, error 3.57e-03
# iter = 777
# vfi ends with 300 iters, error 1.09e-02
# iter = 778
# vfi ends with 300 iters, error 1.15e-02
# iter = 779
# vfi ends with 300 iters, error 9.52e-03
# iter = 780
# vfi ends with 300 iters, error 2.25e-02
# iter = 781
# vfi ends with 300 iters, error 6.78e-03
# iter = 782
# vfi ends with 300 iters, error 6.49e-03
# iter = 783
# vfi ends with 300 iters, error 7.38e-03
# iter = 784
# vfi ends with 300 iters, error 1.85e-02
# iter = 785
# vfi ends with 300 iters, error 9.16e-03
# iter = 786
# vfi ends with 300 iters, error 5.49e-03
# iter = 787
# vfi ends with 300 iters, error 7.56e-03
# iter = 788
# vfi ends with 300 iters, error 1.04e-02
# iter = 789
# vfi ends with 300 iters, error 1.08e-02
# iter = 790
# vfi ends with 300 iters, error 1.02e-02
# iter = 791
# vfi ends with 300 iters, error 3.68e-03
# iter = 792
# vfi ends with 300 iters, error 7.11e-03
# iter = 793
# vfi ends with 300 iters, error 7.34e-03
# iter = 794
# vfi ends with 300 iters, error 8.19e-03
# iter = 795
# vfi ends with 300 iters, error 8.55e-03
# iter = 796
# vfi ends with 300 iters, error 1.86e-02
# iter = 797
# vfi ends with 300 iters, error 1.60e-02
# iter = 798
# vfi ends with 300 iters, error 7.25e-03
# iter = 799
# vfi ends with 300 iters, error 1.43e-02
# iter = 800
# vfi ends with 300 iters, error 1.53e-02
# iter = 801
# vfi ends with 32 iters, error 8.82e-06
# iter = 802
# vfi ends with 32 iters, error 9.30e-06
# iter = 803
# vfi ends with 32 iters, error 9.54e-06
# iter = 804
# vfi ends with 32 iters, error 8.82e-06
# iter = 805
# vfi ends with 32 iters, error 9.06e-06
# iter = 806
# vfi ends with 40 iters, error 8.58e-06
# iter = 807
# vfi ends with 40 iters, error 8.58e-06
# iter = 808
# vfi ends with 40 iters, error 8.58e-06
# iter = 809
# vfi ends with 40 iters, error 8.58e-06
# iter = 810
# vfi ends with 40 iters, error 8.58e-06
# iter = 811
# vfi ends with 52 iters, error 8.11e-06
# iter = 812
# vfi ends with 52 iters, error 8.58e-06
# iter = 813
# vfi ends with 52 iters, error 8.58e-06
# iter = 814
# vfi ends with 52 iters, error 8.11e-06
# iter = 815
# vfi ends with 52 iters, error 8.58e-06
# iter = 816
# vfi ends with 71 iters, error 9.06e-06
# iter = 817
# vfi ends with 71 iters, error 9.06e-06
# iter = 818
# vfi ends with 71 iters, error 9.06e-06
# iter = 819
# vfi ends with 71 iters, error 9.06e-06
# iter = 820
# vfi ends with 71 iters, error 9.06e-06
# iter = 821
# vfi ends with 110 iters, error 9.54e-06
# iter = 822
# vfi ends with 110 iters, error 9.54e-06
# iter = 823
# vfi ends with 110 iters, error 9.54e-06
# iter = 824
# vfi ends with 110 iters, error 9.54e-06
# iter = 825
# vfi ends with 110 iters, error 9.54e-06
# iter = 826
# vfi ends with 33 iters, error 8.34e-06
# iter = 827
# vfi ends with 300 iters, error 2.26e-05
# iter = 828
# vfi ends with 300 iters, error 3.32e-03
# iter = 829
# vfi ends with 300 iters, error 8.59e-04
# iter = 830
# vfi ends with 300 iters, error 7.35e-04
# iter = 831
# vfi ends with 41 iters, error 8.11e-06
# iter = 832
# vfi ends with 138 iters, error 8.58e-06
# iter = 833
# vfi ends with 300 iters, error 4.34e-03
# iter = 834
# vfi ends with 300 iters, error 5.69e-04
# iter = 835
# vfi ends with 300 iters, error 5.63e-04
# iter = 836
# vfi ends with 65 iters, error 7.63e-06
# iter = 837
# vfi ends with 60 iters, error 9.06e-06
# iter = 838
# vfi ends with 300 iters, error 7.78e-03
# iter = 839
# vfi ends with 300 iters, error 8.09e-04
# iter = 840
# vfi ends with 300 iters, error 9.34e-04
# iter = 841
# vfi ends with 110 iters, error 6.68e-06
# iter = 842
# vfi ends with 75 iters, error 8.11e-06
# iter = 843
# vfi ends with 300 iters, error 3.79e-04
# iter = 844
# vfi ends with 300 iters, error 2.09e-04
# iter = 845
# vfi ends with 300 iters, error 3.46e-04
# iter = 846
# vfi ends with 120 iters, error 9.54e-06
# iter = 847
# vfi ends with 300 iters, error 9.54e-05
# iter = 848
# vfi ends with 112 iters, error 9.54e-06
# iter = 849
# vfi ends with 122 iters, error 9.54e-06
# iter = 850
# vfi ends with 114 iters, error 7.63e-06
# iter = 851
# vfi ends with 35 iters, error 6.68e-06
# iter = 852
# vfi ends with 300 iters, error 7.87e-03
# iter = 853
# vfi ends with 300 iters, error 1.76e-03
# iter = 854
# vfi ends with 300 iters, error 1.64e-03
# iter = 855
# vfi ends with 300 iters, error 2.83e-03
# iter = 856
# vfi ends with 192 iters, error 8.58e-06
# iter = 857
# vfi ends with 300 iters, error 4.92e-03
# iter = 858
# vfi ends with 300 iters, error 2.37e-03
# iter = 859
# vfi ends with 300 iters, error 1.75e-03
# iter = 860
# vfi ends with 300 iters, error 2.55e-03
# iter = 861
# vfi ends with 90 iters, error 5.72e-06
# iter = 862
# vfi ends with 300 iters, error 1.02e-02
# iter = 863
# vfi ends with 300 iters, error 6.39e-03
# iter = 864
# vfi ends with 300 iters, error 1.61e-03
# iter = 865
# vfi ends with 300 iters, error 1.84e-03
# iter = 866
# vfi ends with 108 iters, error 9.54e-06
# iter = 867
# vfi ends with 300 iters, error 1.15e-02
# iter = 868
# vfi ends with 300 iters, error 9.31e-04
# iter = 869
# vfi ends with 300 iters, error 6.85e-04
# iter = 870
# vfi ends with 277 iters, error 9.54e-06
# iter = 871
# vfi ends with 119 iters, error 9.54e-06
# iter = 872
# vfi ends with 114 iters, error 8.58e-06
# iter = 873
# vfi ends with 300 iters, error 3.29e-04
# iter = 874
# vfi ends with 121 iters, error 8.58e-06
# iter = 875
# vfi ends with 300 iters, error 2.57e-05
# iter = 876
# vfi ends with 300 iters, error 4.90e-04
# iter = 877
# vfi ends with 300 iters, error 7.73e-03
# iter = 878
# vfi ends with 300 iters, error 2.05e-03
# iter = 879
# vfi ends with 300 iters, error 2.98e-03
# iter = 880
# vfi ends with 300 iters, error 3.42e-03
# iter = 881
# vfi ends with 300 iters, error 2.04e-04
# iter = 882
# vfi ends with 300 iters, error 3.82e-03
# iter = 883
# vfi ends with 300 iters, error 2.88e-03
# iter = 884
# vfi ends with 300 iters, error 2.97e-03
# iter = 885
# vfi ends with 300 iters, error 2.59e-03
# iter = 886
# vfi ends with 300 iters, error 7.73e-04
# iter = 887
# vfi ends with 300 iters, error 1.16e-02
# iter = 888
# vfi ends with 300 iters, error 2.26e-03
# iter = 889
# vfi ends with 300 iters, error 2.39e-03
# iter = 890
# vfi ends with 300 iters, error 7.46e-03
# iter = 891
# vfi ends with 300 iters, error 7.58e-05
# iter = 892
# vfi ends with 300 iters, error 1.29e-02
# iter = 893
# vfi ends with 164 iters, error 9.06e-06
# iter = 894
# vfi ends with 138 iters, error 7.63e-06
# iter = 895
# vfi ends with 104 iters, error 9.54e-06
# iter = 896
# vfi ends with 121 iters, error 8.58e-06
# iter = 897
# vfi ends with 117 iters, error 7.63e-06
# iter = 898
# vfi ends with 300 iters, error 8.73e-04
# iter = 899
# vfi ends with 115 iters, error 9.54e-06
# iter = 900
# vfi ends with 117 iters, error 7.63e-06
# iter = 901
# vfi ends with 300 iters, error 7.35e-03
# iter = 902
# vfi ends with 300 iters, error 2.82e-03
# iter = 903
# vfi ends with 300 iters, error 4.86e-03
# iter = 904
# vfi ends with 300 iters, error 3.78e-03
# iter = 905
# vfi ends with 300 iters, error 5.75e-03
# iter = 906
# vfi ends with 300 iters, error 2.18e-03
# iter = 907
# vfi ends with 300 iters, error 3.43e-03
# iter = 908
# vfi ends with 300 iters, error 3.49e-03
# iter = 909
# vfi ends with 300 iters, error 3.95e-03
# iter = 910
# vfi ends with 300 iters, error 4.41e-03
# iter = 911
# vfi ends with 300 iters, error 6.32e-03
# iter = 912
# vfi ends with 300 iters, error 8.14e-03
# iter = 913
# vfi ends with 300 iters, error 2.16e-03
# iter = 914
# vfi ends with 300 iters, error 5.41e-03
# iter = 915
# vfi ends with 300 iters, error 8.78e-03
# iter = 916
# vfi ends with 300 iters, error 8.57e-03
# iter = 917
# vfi ends with 300 iters, error 1.30e-02
# iter = 918
# vfi ends with 272 iters, error 7.63e-06
# iter = 919
# vfi ends with 300 iters, error 7.30e-05
# iter = 920
# vfi ends with 300 iters, error 7.35e-03
# iter = 921
# vfi ends with 120 iters, error 8.58e-06
# iter = 922
# vfi ends with 300 iters, error 5.31e-04
# iter = 923
# vfi ends with 131 iters, error 9.54e-06
# iter = 924
# vfi ends with 300 iters, error 3.72e-05
# iter = 925
# vfi ends with 122 iters, error 9.54e-06
# iter = 926
# vfi ends with 300 iters, error 1.04e-02
# iter = 927
# vfi ends with 300 iters, error 3.67e-03
# iter = 928
# vfi ends with 300 iters, error 4.95e-03
# iter = 929
# vfi ends with 300 iters, error 8.06e-03
# iter = 930
# vfi ends with 300 iters, error 5.01e-03
# iter = 931
# vfi ends with 300 iters, error 1.16e-02
# iter = 932
# vfi ends with 300 iters, error 3.22e-03
# iter = 933
# vfi ends with 300 iters, error 5.78e-03
# iter = 934
# vfi ends with 300 iters, error 5.46e-03
# iter = 935
# vfi ends with 300 iters, error 1.45e-02
# iter = 936
# vfi ends with 300 iters, error 1.06e-02
# iter = 937
# vfi ends with 300 iters, error 5.98e-03
# iter = 938
# vfi ends with 300 iters, error 8.93e-03
# iter = 939
# vfi ends with 300 iters, error 8.51e-03
# iter = 940
# vfi ends with 300 iters, error 1.21e-02
# iter = 941
# vfi ends with 300 iters, error 1.24e-02
# iter = 942
# vfi ends with 300 iters, error 1.46e-02
# iter = 943
# vfi ends with 300 iters, error 4.96e-05
# iter = 944
# vfi ends with 300 iters, error 6.75e-03
# iter = 945
# vfi ends with 300 iters, error 1.10e-02
# iter = 946
# vfi ends with 300 iters, error 7.98e-03
# iter = 947
# vfi ends with 300 iters, error 3.12e-04
# iter = 948
# vfi ends with 300 iters, error 5.72e-05
# iter = 949
# vfi ends with 152 iters, error 7.63e-06
# iter = 950
# vfi ends with 300 iters, error 5.53e-05
# iter = 951
# vfi ends with 300 iters, error 1.26e-02
# iter = 952
# vfi ends with 300 iters, error 4.37e-03
# iter = 953
# vfi ends with 300 iters, error 5.67e-03
# iter = 954
# vfi ends with 300 iters, error 6.85e-03
# iter = 955
# vfi ends with 300 iters, error 8.58e-03
# iter = 956
# vfi ends with 300 iters, error 1.29e-02
# iter = 957
# vfi ends with 300 iters, error 4.52e-03
# iter = 958
# vfi ends with 300 iters, error 9.83e-03
# iter = 959
# vfi ends with 300 iters, error 1.74e-02
# iter = 960
# vfi ends with 300 iters, error 1.39e-02
# iter = 961
# vfi ends with 300 iters, error 1.03e-02
# iter = 962
# vfi ends with 300 iters, error 5.55e-03
# iter = 963
# vfi ends with 300 iters, error 8.95e-03
# iter = 964
# vfi ends with 300 iters, error 1.07e-02
# iter = 965
# vfi ends with 300 iters, error 1.04e-02
# iter = 966
# vfi ends with 300 iters, error 2.00e-02
# iter = 967
# vfi ends with 300 iters, error 1.48e-02
# iter = 968
# vfi ends with 300 iters, error 1.49e-03
# iter = 969
# vfi ends with 300 iters, error 7.60e-03
# iter = 970
# vfi ends with 300 iters, error 9.43e-03
# iter = 971
# vfi ends with 300 iters, error 1.39e-02
# iter = 972
# vfi ends with 300 iters, error 3.72e-04
# iter = 973
# vfi ends with 300 iters, error 4.96e-05
# iter = 974
# vfi ends with 139 iters, error 7.63e-06
# iter = 975
# vfi ends with 149 iters, error 9.54e-06
# iter = 976
# vfi ends with 300 iters, error 1.41e-02
# iter = 977
# vfi ends with 300 iters, error 4.68e-03
# iter = 978
# vfi ends with 300 iters, error 7.29e-03
# iter = 979
# vfi ends with 300 iters, error 1.17e-02
# iter = 980
# vfi ends with 300 iters, error 1.39e-02
# iter = 981
# vfi ends with 300 iters, error 1.58e-02
# iter = 982
# vfi ends with 300 iters, error 6.53e-03
# iter = 983
# vfi ends with 300 iters, error 8.10e-03
# iter = 984
# vfi ends with 300 iters, error 1.08e-02
# iter = 985
# vfi ends with 300 iters, error 2.07e-02
# iter = 986
# vfi ends with 300 iters, error 1.31e-02
# iter = 987
# vfi ends with 300 iters, error 9.50e-03
# iter = 988
# vfi ends with 300 iters, error 6.86e-03
# iter = 989
# vfi ends with 300 iters, error 1.38e-02
# iter = 990
# vfi ends with 300 iters, error 7.95e-03
# iter = 991
# vfi ends with 300 iters, error 1.34e-02
# iter = 992
# vfi ends with 300 iters, error 1.48e-02
# iter = 993
# vfi ends with 300 iters, error 9.51e-03
# iter = 994
# vfi ends with 300 iters, error 8.75e-03
# iter = 995
# vfi ends with 300 iters, error 9.18e-03
# iter = 996
# vfi ends with 300 iters, error 1.42e-02
# iter = 997
# vfi ends with 300 iters, error 4.50e-04
# iter = 998
# vfi ends with 300 iters, error 5.25e-05
# iter = 999
# vfi ends with 300 iters, error 4.77e-05
# iter = 1000
# vfi ends with 300 iters, error 3.62e-05
# iter = 1001
# vfi ends with 63 iters, error 9.78e-06
# iter = 1002
# vfi ends with 56 iters, error 9.78e-06
# iter = 1003
# vfi ends with 50 iters, error 9.78e-06
# iter = 1004
# vfi ends with 45 iters, error 9.54e-06
# iter = 1005
# vfi ends with 40 iters, error 9.06e-06
# iter = 1006
# vfi ends with 68 iters, error 9.06e-06
# iter = 1007
# vfi ends with 61 iters, error 9.06e-06
# iter = 1008
# vfi ends with 53 iters, error 9.54e-06
# iter = 1009
# vfi ends with 46 iters, error 9.54e-06
# iter = 1010
# vfi ends with 43 iters, error 9.06e-06
# iter = 1011
# vfi ends with 72 iters, error 9.54e-06
# iter = 1012
# vfi ends with 64 iters, error 9.54e-06
# iter = 1013
# vfi ends with 53 iters, error 9.06e-06
# iter = 1014
# vfi ends with 54 iters, error 9.06e-06
# iter = 1015
# vfi ends with 53 iters, error 8.58e-06
# iter = 1016
# vfi ends with 71 iters, error 8.58e-06
# iter = 1017
# vfi ends with 71 iters, error 9.06e-06
# iter = 1018
# vfi ends with 71 iters, error 9.54e-06
# iter = 1019
# vfi ends with 72 iters, error 8.58e-06
# iter = 1020
# vfi ends with 72 iters, error 8.58e-06
# iter = 1021
# vfi ends with 109 iters, error 9.54e-06
# iter = 1022
# vfi ends with 110 iters, error 9.54e-06
# iter = 1023
# vfi ends with 111 iters, error 9.54e-06
# iter = 1024
# vfi ends with 111 iters, error 9.54e-06
# iter = 1025
# vfi ends with 111 iters, error 9.54e-06
# iter = 1026
# vfi ends with 300 iters, error 3.63e-03
# iter = 1027
# vfi ends with 300 iters, error 5.47e-03
# iter = 1028
# vfi ends with 300 iters, error 5.55e-03
# iter = 1029
# vfi ends with 300 iters, error 6.40e-03
# iter = 1030
# vfi ends with 300 iters, error 7.20e-03
# iter = 1031
# vfi ends with 300 iters, error 3.48e-03
# iter = 1032
# vfi ends with 300 iters, error 4.50e-03
# iter = 1033
# vfi ends with 300 iters, error 5.98e-03
# iter = 1034
# vfi ends with 300 iters, error 5.92e-03
# iter = 1035
# vfi ends with 300 iters, error 6.05e-03
# iter = 1036
# vfi ends with 300 iters, error 3.50e-03
# iter = 1037
# vfi ends with 300 iters, error 5.39e-03
# iter = 1038
# vfi ends with 300 iters, error 4.15e-03
# iter = 1039
# vfi ends with 300 iters, error 5.53e-03
# iter = 1040
# vfi ends with 300 iters, error 6.36e-03
# iter = 1041
# vfi ends with 300 iters, error 2.21e-03
# iter = 1042
# vfi ends with 300 iters, error 4.01e-03
# iter = 1043
# vfi ends with 300 iters, error 4.27e-03
# iter = 1044
# vfi ends with 300 iters, error 5.29e-03
# iter = 1045
# vfi ends with 300 iters, error 4.48e-03
# iter = 1046
# vfi ends with 300 iters, error 1.34e-03
# iter = 1047
# vfi ends with 300 iters, error 2.80e-03
# iter = 1048
# vfi ends with 300 iters, error 2.92e-03
# iter = 1049
# vfi ends with 300 iters, error 4.08e-03
# iter = 1050
# vfi ends with 300 iters, error 4.79e-03
# iter = 1051
# vfi ends with 300 iters, error 5.14e-03
# iter = 1052
# vfi ends with 300 iters, error 7.43e-03
# iter = 1053
# vfi ends with 300 iters, error 7.87e-03
# iter = 1054
# vfi ends with 300 iters, error 1.03e-02
# iter = 1055
# vfi ends with 300 iters, error 9.66e-03
# iter = 1056
# vfi ends with 300 iters, error 4.95e-03
# iter = 1057
# vfi ends with 300 iters, error 5.79e-03
# iter = 1058
# vfi ends with 300 iters, error 7.02e-03
# iter = 1059
# vfi ends with 300 iters, error 9.39e-03
# iter = 1060
# vfi ends with 300 iters, error 8.07e-03
# iter = 1061
# vfi ends with 300 iters, error 4.85e-03
# iter = 1062
# vfi ends with 300 iters, error 5.13e-03
# iter = 1063
# vfi ends with 300 iters, error 8.34e-03
# iter = 1064
# vfi ends with 300 iters, error 6.98e-03
# iter = 1065
# vfi ends with 300 iters, error 7.93e-03
# iter = 1066
# vfi ends with 300 iters, error 3.63e-03
# iter = 1067
# vfi ends with 300 iters, error 5.16e-03
# iter = 1068
# vfi ends with 300 iters, error 5.54e-03
# iter = 1069
# vfi ends with 300 iters, error 5.93e-03
# iter = 1070
# vfi ends with 300 iters, error 6.44e-03
# iter = 1071
# vfi ends with 300 iters, error 2.40e-03
# iter = 1072
# vfi ends with 300 iters, error 2.99e-03
# iter = 1073
# vfi ends with 300 iters, error 2.98e-03
# iter = 1074
# vfi ends with 300 iters, error 5.31e-03
# iter = 1075
# vfi ends with 300 iters, error 5.65e-03
# iter = 1076
# vfi ends with 300 iters, error 5.79e-03
# iter = 1077
# vfi ends with 300 iters, error 8.92e-03
# iter = 1078
# vfi ends with 300 iters, error 9.18e-03
# iter = 1079
# vfi ends with 300 iters, error 1.59e-02
# iter = 1080
# vfi ends with 300 iters, error 1.24e-02
# iter = 1081
# vfi ends with 300 iters, error 6.10e-03
# iter = 1082
# vfi ends with 300 iters, error 5.81e-03
# iter = 1083
# vfi ends with 300 iters, error 9.66e-03
# iter = 1084
# vfi ends with 300 iters, error 1.59e-02
# iter = 1085
# vfi ends with 300 iters, error 1.04e-02
# iter = 1086
# vfi ends with 300 iters, error 5.11e-03
# iter = 1087
# vfi ends with 300 iters, error 6.65e-03
# iter = 1088
# vfi ends with 300 iters, error 9.19e-03
# iter = 1089
# vfi ends with 300 iters, error 6.21e-03
# iter = 1090
# vfi ends with 300 iters, error 8.28e-03
# iter = 1091
# vfi ends with 300 iters, error 3.42e-03
# iter = 1092
# vfi ends with 300 iters, error 3.91e-03
# iter = 1093
# vfi ends with 300 iters, error 7.37e-03
# iter = 1094
# vfi ends with 300 iters, error 7.52e-03
# iter = 1095
# vfi ends with 300 iters, error 7.26e-03
# iter = 1096
# vfi ends with 300 iters, error 2.70e-03
# iter = 1097
# vfi ends with 300 iters, error 4.84e-03
# iter = 1098
# vfi ends with 300 iters, error 5.16e-03
# iter = 1099
# vfi ends with 300 iters, error 4.20e-03
# iter = 1100
# vfi ends with 300 iters, error 6.31e-03
# iter = 1101
# vfi ends with 300 iters, error 6.51e-03
# iter = 1102
# vfi ends with 300 iters, error 1.04e-02
# iter = 1103
# vfi ends with 300 iters, error 1.27e-02
# iter = 1104
# vfi ends with 300 iters, error 1.80e-02
# iter = 1105
# vfi ends with 300 iters, error 1.32e-02
# iter = 1106
# vfi ends with 300 iters, error 7.14e-03
# iter = 1107
# vfi ends with 300 iters, error 7.46e-03
# iter = 1108
# vfi ends with 300 iters, error 8.27e-03
# iter = 1109
# vfi ends with 300 iters, error 1.06e-02
# iter = 1110
# vfi ends with 300 iters, error 1.75e-02
# iter = 1111
# vfi ends with 300 iters, error 6.06e-03
# iter = 1112
# vfi ends with 300 iters, error 8.17e-03
# iter = 1113
# vfi ends with 300 iters, error 8.16e-03
# iter = 1114
# vfi ends with 300 iters, error 1.01e-02
# iter = 1115
# vfi ends with 300 iters, error 1.10e-02
# iter = 1116
# vfi ends with 300 iters, error 5.26e-03
# iter = 1117
# vfi ends with 300 iters, error 5.39e-03
# iter = 1118
# vfi ends with 300 iters, error 7.05e-03
# iter = 1119
# vfi ends with 300 iters, error 9.13e-03
# iter = 1120
# vfi ends with 300 iters, error 9.27e-03
# iter = 1121
# vfi ends with 300 iters, error 3.23e-03
# iter = 1122
# vfi ends with 300 iters, error 3.97e-03
# iter = 1123
# vfi ends with 300 iters, error 6.34e-03
# iter = 1124
# vfi ends with 300 iters, error 5.82e-03
# iter = 1125
# vfi ends with 300 iters, error 9.02e-03
# iter = 1126
# vfi ends with 300 iters, error 9.12e-03
# iter = 1127
# vfi ends with 300 iters, error 9.40e-03
# iter = 1128
# vfi ends with 300 iters, error 1.34e-02
# iter = 1129
# vfi ends with 300 iters, error 1.36e-02
# iter = 1130
# vfi ends with 300 iters, error 1.42e-02
# iter = 1131
# vfi ends with 300 iters, error 7.07e-03
# iter = 1132
# vfi ends with 300 iters, error 8.52e-03
# iter = 1133
# vfi ends with 300 iters, error 1.31e-02
# iter = 1134
# vfi ends with 300 iters, error 1.06e-02
# iter = 1135
# vfi ends with 300 iters, error 1.43e-02
# iter = 1136
# vfi ends with 300 iters, error 6.21e-03
# iter = 1137
# vfi ends with 300 iters, error 8.49e-03
# iter = 1138
# vfi ends with 300 iters, error 9.87e-03
# iter = 1139
# vfi ends with 300 iters, error 7.19e-03
# iter = 1140
# vfi ends with 300 iters, error 7.37e-03
# iter = 1141
# vfi ends with 300 iters, error 4.97e-03
# iter = 1142
# vfi ends with 300 iters, error 8.17e-03
# iter = 1143
# vfi ends with 300 iters, error 7.28e-03
# iter = 1144
# vfi ends with 300 iters, error 1.19e-02
# iter = 1145
# vfi ends with 300 iters, error 1.16e-02
# iter = 1146
# vfi ends with 300 iters, error 2.81e-03
# iter = 1147
# vfi ends with 300 iters, error 4.78e-03
# iter = 1148
# vfi ends with 300 iters, error 8.45e-03
# iter = 1149
# vfi ends with 300 iters, error 9.48e-03
# iter = 1150
# vfi ends with 300 iters, error 7.07e-03
# iter = 1151
# vfi ends with 300 iters, error 7.38e-03
# iter = 1152
# vfi ends with 300 iters, error 1.25e-02
# iter = 1153
# vfi ends with 300 iters, error 1.35e-02
# iter = 1154
# vfi ends with 300 iters, error 1.60e-02
# iter = 1155
# vfi ends with 300 iters, error 2.34e-02
# iter = 1156
# vfi ends with 300 iters, error 5.62e-03
# iter = 1157
# vfi ends with 300 iters, error 9.41e-03
# iter = 1158
# vfi ends with 300 iters, error 9.36e-03
# iter = 1159
# vfi ends with 300 iters, error 1.08e-02
# iter = 1160
# vfi ends with 300 iters, error 1.65e-02
# iter = 1161
# vfi ends with 300 iters, error 6.67e-03
# iter = 1162
# vfi ends with 300 iters, error 9.07e-03
# iter = 1163
# vfi ends with 300 iters, error 1.14e-02
# iter = 1164
# vfi ends with 300 iters, error 1.06e-02
# iter = 1165
# vfi ends with 300 iters, error 1.23e-02
# iter = 1166
# vfi ends with 300 iters, error 6.17e-03
# iter = 1167
# vfi ends with 300 iters, error 6.51e-03
# iter = 1168
# vfi ends with 300 iters, error 8.45e-03
# iter = 1169
# vfi ends with 300 iters, error 1.17e-02
# iter = 1170
# vfi ends with 300 iters, error 8.65e-03
# iter = 1171
# vfi ends with 300 iters, error 4.51e-03
# iter = 1172
# vfi ends with 300 iters, error 5.70e-03
# iter = 1173
# vfi ends with 300 iters, error 7.25e-03
# iter = 1174
# vfi ends with 300 iters, error 7.99e-03
# iter = 1175
# vfi ends with 300 iters, error 1.14e-02
# iter = 1176
# vfi ends with 300 iters, error 9.58e-03
# iter = 1177
# vfi ends with 300 iters, error 1.01e-02
# iter = 1178
# vfi ends with 300 iters, error 1.41e-02
# iter = 1179
# vfi ends with 300 iters, error 1.32e-02
# iter = 1180
# vfi ends with 300 iters, error 1.43e-02
# iter = 1181
# vfi ends with 300 iters, error 5.27e-03
# iter = 1182
# vfi ends with 300 iters, error 1.14e-02
# iter = 1183
# vfi ends with 300 iters, error 1.41e-02
# iter = 1184
# vfi ends with 300 iters, error 1.08e-02
# iter = 1185
# vfi ends with 300 iters, error 1.14e-02
# iter = 1186
# vfi ends with 300 iters, error 7.17e-03
# iter = 1187
# vfi ends with 300 iters, error 6.95e-03
# iter = 1188
# vfi ends with 300 iters, error 9.51e-03
# iter = 1189
# vfi ends with 300 iters, error 1.62e-02
# iter = 1190
# vfi ends with 300 iters, error 1.52e-02
# iter = 1191
# vfi ends with 300 iters, error 3.96e-03
# iter = 1192
# vfi ends with 300 iters, error 6.13e-03
# iter = 1193
# vfi ends with 300 iters, error 8.00e-03
# iter = 1194
# vfi ends with 300 iters, error 8.52e-03
# iter = 1195
# vfi ends with 300 iters, error 9.49e-03
# iter = 1196
# vfi ends with 300 iters, error 3.62e-03
# iter = 1197
# vfi ends with 300 iters, error 7.23e-03
# iter = 1198
# vfi ends with 300 iters, error 6.84e-03
# iter = 1199
# vfi ends with 300 iters, error 7.01e-03
# iter = 1200
# vfi ends with 300 iters, error 7.71e-03
# iter = 1201
# vfi ends with 38 iters, error 9.06e-06
# iter = 1202
# vfi ends with 37 iters, error 9.78e-06
# iter = 1203
# vfi ends with 36 iters, error 9.06e-06
# iter = 1204
# vfi ends with 35 iters, error 8.11e-06
# iter = 1205
# vfi ends with 34 iters, error 7.63e-06
# iter = 1206
# vfi ends with 42 iters, error 8.11e-06
# iter = 1207
# vfi ends with 41 iters, error 8.58e-06
# iter = 1208
# vfi ends with 41 iters, error 8.11e-06
# iter = 1209
# vfi ends with 40 iters, error 9.54e-06
# iter = 1210
# vfi ends with 40 iters, error 9.54e-06
# iter = 1211
# vfi ends with 52 iters, error 8.58e-06
# iter = 1212
# vfi ends with 52 iters, error 8.58e-06
# iter = 1213
# vfi ends with 52 iters, error 8.58e-06
# iter = 1214
# vfi ends with 52 iters, error 8.58e-06
# iter = 1215
# vfi ends with 52 iters, error 8.58e-06
# iter = 1216
# vfi ends with 71 iters, error 9.54e-06
# iter = 1217
# vfi ends with 71 iters, error 9.54e-06
# iter = 1218
# vfi ends with 71 iters, error 9.54e-06
# iter = 1219
# vfi ends with 71 iters, error 9.54e-06
# iter = 1220
# vfi ends with 71 iters, error 9.54e-06
# iter = 1221
# vfi ends with 111 iters, error 9.54e-06
# iter = 1222
# vfi ends with 111 iters, error 9.54e-06
# iter = 1223
# vfi ends with 111 iters, error 9.54e-06
# iter = 1224
# vfi ends with 111 iters, error 9.54e-06
# iter = 1225
# vfi ends with 111 iters, error 9.54e-06
# iter = 1226
# vfi ends with 300 iters, error 2.61e-03
# iter = 1227
# vfi ends with 300 iters, error 5.07e-03
# iter = 1228
# vfi ends with 300 iters, error 6.98e-03
# iter = 1229
# vfi ends with 300 iters, error 9.66e-03
# iter = 1230
# vfi ends with 300 iters, error 6.99e-03
# iter = 1231
# vfi ends with 300 iters, error 2.25e-03
# iter = 1232
# vfi ends with 300 iters, error 4.70e-03
# iter = 1233
# vfi ends with 300 iters, error 5.49e-03
# iter = 1234
# vfi ends with 300 iters, error 6.44e-03
# iter = 1235
# vfi ends with 300 iters, error 6.43e-03
# iter = 1236
# vfi ends with 300 iters, error 3.18e-03
# iter = 1237
# vfi ends with 300 iters, error 4.16e-03
# iter = 1238
# vfi ends with 300 iters, error 4.86e-03
# iter = 1239
# vfi ends with 300 iters, error 5.91e-03
# iter = 1240
# vfi ends with 300 iters, error 6.77e-03
# iter = 1241
# vfi ends with 300 iters, error 2.08e-03
# iter = 1242
# vfi ends with 300 iters, error 3.47e-03
# iter = 1243
# vfi ends with 300 iters, error 3.87e-03
# iter = 1244
# vfi ends with 300 iters, error 5.07e-03
# iter = 1245
# vfi ends with 300 iters, error 7.82e-03
# iter = 1246
# vfi ends with 300 iters, error 3.83e-03
# iter = 1247
# vfi ends with 300 iters, error 2.03e-03
# iter = 1248
# vfi ends with 300 iters, error 3.96e-03
# iter = 1249
# vfi ends with 300 iters, error 4.43e-03
# iter = 1250
# vfi ends with 300 iters, error 4.74e-03
# iter = 1251
# vfi ends with 300 iters, error 4.54e-03
# iter = 1252
# vfi ends with 300 iters, error 6.78e-03
# iter = 1253
# vfi ends with 300 iters, error 9.32e-03
# iter = 1254
# vfi ends with 300 iters, error 1.32e-02
# iter = 1255
# vfi ends with 300 iters, error 9.91e-03
# iter = 1256
# vfi ends with 300 iters, error 3.99e-03
# iter = 1257
# vfi ends with 300 iters, error 6.01e-03
# iter = 1258
# vfi ends with 300 iters, error 6.75e-03
# iter = 1259
# vfi ends with 300 iters, error 1.36e-02
# iter = 1260
# vfi ends with 300 iters, error 8.83e-03
# iter = 1261
# vfi ends with 300 iters, error 3.11e-03
# iter = 1262
# vfi ends with 300 iters, error 4.73e-03
# iter = 1263
# vfi ends with 300 iters, error 5.19e-03
# iter = 1264
# vfi ends with 300 iters, error 5.70e-03
# iter = 1265
# vfi ends with 300 iters, error 6.07e-03
# iter = 1266
# vfi ends with 300 iters, error 3.12e-03
# iter = 1267
# vfi ends with 300 iters, error 3.15e-03
# iter = 1268
# vfi ends with 300 iters, error 5.59e-03
# iter = 1269
# vfi ends with 300 iters, error 4.65e-03
# iter = 1270
# vfi ends with 300 iters, error 4.17e-03
# iter = 1271
# vfi ends with 300 iters, error 6.17e-03
# iter = 1272
# vfi ends with 300 iters, error 3.15e-03
# iter = 1273
# vfi ends with 300 iters, error 3.92e-03
# iter = 1274
# vfi ends with 300 iters, error 6.62e-03
# iter = 1275
# vfi ends with 300 iters, error 6.27e-03
# iter = 1276
# vfi ends with 300 iters, error 5.46e-03
# iter = 1277
# vfi ends with 300 iters, error 7.40e-03
# iter = 1278
# vfi ends with 300 iters, error 1.53e-02
# iter = 1279
# vfi ends with 300 iters, error 1.51e-02
# iter = 1280
# vfi ends with 300 iters, error 1.13e-02
# iter = 1281
# vfi ends with 300 iters, error 6.70e-03
# iter = 1282
# vfi ends with 300 iters, error 6.97e-03
# iter = 1283
# vfi ends with 300 iters, error 8.27e-03
# iter = 1284
# vfi ends with 300 iters, error 1.32e-02
# iter = 1285
# vfi ends with 300 iters, error 1.05e-02
# iter = 1286
# vfi ends with 300 iters, error 4.02e-03
# iter = 1287
# vfi ends with 300 iters, error 7.44e-03
# iter = 1288
# vfi ends with 300 iters, error 6.31e-03
# iter = 1289
# vfi ends with 300 iters, error 7.99e-03
# iter = 1290
# vfi ends with 300 iters, error 1.35e-02
# iter = 1291
# vfi ends with 300 iters, error 2.52e-03
# iter = 1292
# vfi ends with 300 iters, error 6.50e-03
# iter = 1293
# vfi ends with 300 iters, error 7.05e-03
# iter = 1294
# vfi ends with 300 iters, error 7.38e-03
# iter = 1295
# vfi ends with 300 iters, error 8.42e-03
# iter = 1296
# vfi ends with 300 iters, error 2.89e-03
# iter = 1297
# vfi ends with 300 iters, error 5.43e-03
# iter = 1298
# vfi ends with 300 iters, error 4.99e-03
# iter = 1299
# vfi ends with 300 iters, error 6.39e-03
# iter = 1300
# vfi ends with 300 iters, error 7.95e-03
# iter = 1301
# vfi ends with 300 iters, error 5.88e-03
# iter = 1302
# vfi ends with 300 iters, error 9.79e-03
# iter = 1303
# vfi ends with 300 iters, error 1.63e-02
# iter = 1304
# vfi ends with 300 iters, error 1.73e-02
# iter = 1305
# vfi ends with 300 iters, error 1.47e-02
# iter = 1306
# vfi ends with 300 iters, error 5.52e-03
# iter = 1307
# vfi ends with 300 iters, error 1.17e-02
# iter = 1308
# vfi ends with 300 iters, error 9.93e-03
# iter = 1309
# vfi ends with 300 iters, error 1.15e-02
# iter = 1310
# vfi ends with 300 iters, error 1.28e-02
# iter = 1311
# vfi ends with 300 iters, error 5.26e-03
# iter = 1312
# vfi ends with 300 iters, error 5.67e-03
# iter = 1313
# vfi ends with 300 iters, error 9.34e-03
# iter = 1314
# vfi ends with 300 iters, error 7.49e-03
# iter = 1315
# vfi ends with 300 iters, error 9.62e-03
# iter = 1316
# vfi ends with 300 iters, error 4.23e-03
# iter = 1317
# vfi ends with 300 iters, error 7.13e-03
# iter = 1318
# vfi ends with 300 iters, error 6.70e-03
# iter = 1319
# vfi ends with 300 iters, error 7.71e-03
# iter = 1320
# vfi ends with 300 iters, error 7.36e-03
# iter = 1321
# vfi ends with 300 iters, error 3.97e-03
# iter = 1322
# vfi ends with 300 iters, error 5.60e-03
# iter = 1323
# vfi ends with 300 iters, error 4.69e-03
# iter = 1324
# vfi ends with 300 iters, error 5.76e-03
# iter = 1325
# vfi ends with 300 iters, error 6.25e-03
# iter = 1326
# vfi ends with 300 iters, error 7.90e-03
# iter = 1327
# vfi ends with 300 iters, error 1.01e-02
# iter = 1328
# vfi ends with 300 iters, error 1.25e-02
# iter = 1329
# vfi ends with 300 iters, error 1.33e-02
# iter = 1330
# vfi ends with 300 iters, error 1.49e-02
# iter = 1331
# vfi ends with 300 iters, error 5.38e-03
# iter = 1332
# vfi ends with 300 iters, error 1.05e-02
# iter = 1333
# vfi ends with 300 iters, error 1.04e-02
# iter = 1334
# vfi ends with 300 iters, error 1.24e-02
# iter = 1335
# vfi ends with 300 iters, error 1.10e-02
# iter = 1336
# vfi ends with 300 iters, error 5.90e-03
# iter = 1337
# vfi ends with 300 iters, error 8.57e-03
# iter = 1338
# vfi ends with 300 iters, error 8.70e-03
# iter = 1339
# vfi ends with 300 iters, error 1.23e-02
# iter = 1340
# vfi ends with 300 iters, error 1.17e-02
# iter = 1341
# vfi ends with 300 iters, error 4.39e-03
# iter = 1342
# vfi ends with 300 iters, error 7.54e-03
# iter = 1343
# vfi ends with 300 iters, error 8.28e-03
# iter = 1344
# vfi ends with 300 iters, error 7.13e-03
# iter = 1345
# vfi ends with 300 iters, error 6.93e-03
# iter = 1346
# vfi ends with 300 iters, error 4.82e-03
# iter = 1347
# vfi ends with 300 iters, error 4.77e-03
# iter = 1348
# vfi ends with 300 iters, error 6.90e-03
# iter = 1349
# vfi ends with 300 iters, error 8.52e-03
# iter = 1350
# vfi ends with 300 iters, error 9.17e-03
# iter = 1351
# vfi ends with 300 iters, error 7.03e-03
# iter = 1352
# vfi ends with 300 iters, error 1.36e-02
# iter = 1353
# vfi ends with 300 iters, error 1.73e-02
# iter = 1354
# vfi ends with 300 iters, error 2.17e-02
# iter = 1355
# vfi ends with 300 iters, error 2.03e-02
# iter = 1356
# vfi ends with 300 iters, error 6.69e-03
# iter = 1357
# vfi ends with 300 iters, error 1.13e-02
# iter = 1358
# vfi ends with 300 iters, error 1.51e-02
# iter = 1359
# vfi ends with 300 iters, error 1.10e-02
# iter = 1360
# vfi ends with 300 iters, error 1.27e-02
# iter = 1361
# vfi ends with 300 iters, error 6.92e-03
# iter = 1362
# vfi ends with 300 iters, error 7.92e-03
# iter = 1363
# vfi ends with 300 iters, error 7.47e-03
# iter = 1364
# vfi ends with 300 iters, error 1.54e-02
# iter = 1365
# vfi ends with 300 iters, error 1.73e-02
# iter = 1366
# vfi ends with 300 iters, error 5.45e-03
# iter = 1367
# vfi ends with 300 iters, error 7.22e-03
# iter = 1368
# vfi ends with 300 iters, error 8.91e-03
# iter = 1369
# vfi ends with 300 iters, error 8.41e-03
# iter = 1370
# vfi ends with 300 iters, error 8.58e-03
# iter = 1371
# vfi ends with 300 iters, error 4.31e-03
# iter = 1372
# vfi ends with 300 iters, error 7.04e-03
# iter = 1373
# vfi ends with 300 iters, error 7.79e-03
# iter = 1374
# vfi ends with 300 iters, error 7.90e-03
# iter = 1375
# vfi ends with 300 iters, error 7.80e-03
# iter = 1376
# vfi ends with 300 iters, error 1.02e-02
# iter = 1377
# vfi ends with 300 iters, error 1.30e-02
# iter = 1378
# vfi ends with 300 iters, error 1.39e-02
# iter = 1379
# vfi ends with 300 iters, error 1.33e-02
# iter = 1380
# vfi ends with 300 iters, error 1.43e-02
# iter = 1381
# vfi ends with 300 iters, error 7.11e-03
# iter = 1382
# vfi ends with 300 iters, error 1.14e-02
# iter = 1383
# vfi ends with 300 iters, error 1.30e-02
# iter = 1384
# vfi ends with 300 iters, error 1.12e-02
# iter = 1385
# vfi ends with 300 iters, error 2.06e-02
# iter = 1386
# vfi ends with 300 iters, error 5.53e-03
# iter = 1387
# vfi ends with 300 iters, error 9.50e-03
# iter = 1388
# vfi ends with 300 iters, error 1.20e-02
# iter = 1389
# vfi ends with 300 iters, error 1.02e-02
# iter = 1390
# vfi ends with 300 iters, error 1.03e-02
# iter = 1391
# vfi ends with 300 iters, error 3.57e-03
# iter = 1392
# vfi ends with 300 iters, error 7.21e-03
# iter = 1393
# vfi ends with 300 iters, error 8.88e-03
# iter = 1394
# vfi ends with 300 iters, error 1.27e-02
# iter = 1395
# vfi ends with 300 iters, error 1.40e-02
# iter = 1396
# vfi ends with 300 iters, error 6.06e-03
# iter = 1397
# vfi ends with 300 iters, error 8.76e-03
# iter = 1398
# vfi ends with 300 iters, error 8.60e-03
# iter = 1399
# vfi ends with 300 iters, error 8.67e-03
# iter = 1400
# vfi ends with 300 iters, error 1.17e-02
# iter = 1401
# vfi ends with 32 iters, error 9.06e-06
# iter = 1402
# vfi ends with 32 iters, error 9.06e-06
# iter = 1403
# vfi ends with 32 iters, error 9.54e-06
# iter = 1404
# vfi ends with 32 iters, error 9.06e-06
# iter = 1405
# vfi ends with 32 iters, error 9.06e-06
# iter = 1406
# vfi ends with 40 iters, error 8.58e-06
# iter = 1407
# vfi ends with 40 iters, error 9.06e-06
# iter = 1408
# vfi ends with 40 iters, error 8.58e-06
# iter = 1409
# vfi ends with 40 iters, error 9.06e-06
# iter = 1410
# vfi ends with 40 iters, error 8.58e-06
# iter = 1411
# vfi ends with 52 iters, error 8.58e-06
# iter = 1412
# vfi ends with 52 iters, error 8.58e-06
# iter = 1413
# vfi ends with 52 iters, error 8.11e-06
# iter = 1414
# vfi ends with 52 iters, error 8.58e-06
# iter = 1415
# vfi ends with 52 iters, error 8.58e-06
# iter = 1416
# vfi ends with 71 iters, error 9.06e-06
# iter = 1417
# vfi ends with 71 iters, error 9.06e-06
# iter = 1418
# vfi ends with 71 iters, error 9.06e-06
# iter = 1419
# vfi ends with 71 iters, error 9.54e-06
# iter = 1420
# vfi ends with 71 iters, error 9.06e-06
# iter = 1421
# vfi ends with 110 iters, error 9.54e-06
# iter = 1422
# vfi ends with 110 iters, error 9.54e-06
# iter = 1423
# vfi ends with 110 iters, error 9.54e-06
# iter = 1424
# vfi ends with 110 iters, error 9.54e-06
# iter = 1425
# vfi ends with 110 iters, error 9.54e-06
# iter = 1426
# vfi ends with 300 iters, error 7.06e-04
# iter = 1427
# vfi ends with 300 iters, error 3.59e-03
# iter = 1428
# vfi ends with 300 iters, error 3.63e-03
# iter = 1429
# vfi ends with 300 iters, error 6.16e-03
# iter = 1430
# vfi ends with 300 iters, error 5.89e-03
# iter = 1431
# vfi ends with 300 iters, error 2.54e-03
# iter = 1432
# vfi ends with 300 iters, error 3.31e-03
# iter = 1433
# vfi ends with 300 iters, error 4.48e-03
# iter = 1434
# vfi ends with 300 iters, error 5.44e-03
# iter = 1435
# vfi ends with 300 iters, error 6.09e-03
# iter = 1436
# vfi ends with 300 iters, error 1.68e-03
# iter = 1437
# vfi ends with 300 iters, error 3.26e-03
# iter = 1438
# vfi ends with 300 iters, error 3.86e-03
# iter = 1439
# vfi ends with 300 iters, error 4.42e-03
# iter = 1440
# vfi ends with 300 iters, error 5.23e-03
# iter = 1441
# vfi ends with 300 iters, error 2.26e-03
# iter = 1442
# vfi ends with 300 iters, error 4.14e-03
# iter = 1443
# vfi ends with 300 iters, error 4.13e-03
# iter = 1444
# vfi ends with 300 iters, error 4.11e-03
# iter = 1445
# vfi ends with 300 iters, error 4.94e-03
# iter = 1446
# vfi ends with 300 iters, error 7.00e-03
# iter = 1447
# vfi ends with 300 iters, error 1.09e-04
# iter = 1448
# vfi ends with 300 iters, error 2.31e-03
# iter = 1449
# vfi ends with 300 iters, error 2.26e-03
# iter = 1450
# vfi ends with 300 iters, error 1.17e-03
# iter = 1451
# vfi ends with 300 iters, error 3.26e-03
# iter = 1452
# vfi ends with 300 iters, error 6.03e-03
# iter = 1453
# vfi ends with 300 iters, error 7.74e-03
# iter = 1454
# vfi ends with 300 iters, error 1.10e-02
# iter = 1455
# vfi ends with 300 iters, error 1.28e-02
# iter = 1456
# vfi ends with 300 iters, error 3.90e-03
# iter = 1457
# vfi ends with 300 iters, error 5.19e-03
# iter = 1458
# vfi ends with 300 iters, error 6.26e-03
# iter = 1459
# vfi ends with 300 iters, error 7.04e-03
# iter = 1460
# vfi ends with 300 iters, error 8.44e-03
# iter = 1461
# vfi ends with 300 iters, error 3.09e-03
# iter = 1462
# vfi ends with 300 iters, error 4.62e-03
# iter = 1463
# vfi ends with 300 iters, error 5.12e-03
# iter = 1464
# vfi ends with 300 iters, error 6.67e-03
# iter = 1465
# vfi ends with 300 iters, error 6.35e-03
# iter = 1466
# vfi ends with 300 iters, error 3.32e-03
# iter = 1467
# vfi ends with 300 iters, error 6.10e-03
# iter = 1468
# vfi ends with 300 iters, error 4.50e-03
# iter = 1469
# vfi ends with 300 iters, error 4.76e-03
# iter = 1470
# vfi ends with 300 iters, error 4.76e-03
# iter = 1471
# vfi ends with 300 iters, error 9.45e-03
# iter = 1472
# vfi ends with 300 iters, error 6.12e-03
# iter = 1473
# vfi ends with 300 iters, error 4.51e-03
# iter = 1474
# vfi ends with 300 iters, error 4.77e-03
# iter = 1475
# vfi ends with 300 iters, error 5.46e-03
# iter = 1476
# vfi ends with 300 iters, error 3.91e-03
# iter = 1477
# vfi ends with 300 iters, error 7.18e-03
# iter = 1478
# vfi ends with 300 iters, error 1.36e-02
# iter = 1479
# vfi ends with 300 iters, error 1.02e-02
# iter = 1480
# vfi ends with 300 iters, error 1.20e-02
# iter = 1481
# vfi ends with 300 iters, error 4.57e-03
# iter = 1482
# vfi ends with 300 iters, error 5.99e-03
# iter = 1483
# vfi ends with 300 iters, error 7.56e-03
# iter = 1484
# vfi ends with 300 iters, error 8.78e-03
# iter = 1485
# vfi ends with 300 iters, error 1.50e-02
# iter = 1486
# vfi ends with 300 iters, error 4.03e-03
# iter = 1487
# vfi ends with 300 iters, error 5.67e-03
# iter = 1488
# vfi ends with 300 iters, error 7.76e-03
# iter = 1489
# vfi ends with 300 iters, error 6.79e-03
# iter = 1490
# vfi ends with 300 iters, error 1.15e-02
# iter = 1491
# vfi ends with 300 iters, error 4.63e-03
# iter = 1492
# vfi ends with 300 iters, error 4.27e-03
# iter = 1493
# vfi ends with 300 iters, error 5.34e-03
# iter = 1494
# vfi ends with 300 iters, error 5.94e-03
# iter = 1495
# vfi ends with 300 iters, error 6.51e-03
# iter = 1496
# vfi ends with 300 iters, error 1.14e-02
# iter = 1497
# vfi ends with 300 iters, error 3.68e-03
# iter = 1498
# vfi ends with 300 iters, error 3.75e-03
# iter = 1499
# vfi ends with 300 iters, error 6.74e-03
# iter = 1500
# vfi ends with 300 iters, error 5.84e-03
# iter = 1501
# vfi ends with 300 iters, error 5.09e-03
# iter = 1502
# vfi ends with 300 iters, error 8.48e-03
# iter = 1503
# vfi ends with 300 iters, error 1.36e-02
# iter = 1504
# vfi ends with 300 iters, error 1.02e-02
# iter = 1505
# vfi ends with 300 iters, error 1.84e-02
# iter = 1506
# vfi ends with 300 iters, error 4.15e-03
# iter = 1507
# vfi ends with 300 iters, error 6.57e-03
# iter = 1508
# vfi ends with 300 iters, error 9.71e-03
# iter = 1509
# vfi ends with 300 iters, error 9.70e-03
# iter = 1510
# vfi ends with 300 iters, error 1.12e-02
# iter = 1511
# vfi ends with 300 iters, error 4.14e-03
# iter = 1512
# vfi ends with 300 iters, error 5.64e-03
# iter = 1513
# vfi ends with 300 iters, error 8.73e-03
# iter = 1514
# vfi ends with 300 iters, error 8.91e-03
# iter = 1515
# vfi ends with 300 iters, error 8.05e-03
# iter = 1516
# vfi ends with 300 iters, error 5.25e-03
# iter = 1517
# vfi ends with 300 iters, error 4.59e-03
# iter = 1518
# vfi ends with 300 iters, error 5.71e-03
# iter = 1519
# vfi ends with 300 iters, error 6.49e-03
# iter = 1520
# vfi ends with 300 iters, error 8.45e-03
# iter = 1521
# vfi ends with 300 iters, error 1.27e-02
# iter = 1522
# vfi ends with 300 iters, error 3.84e-03
# iter = 1523
# vfi ends with 300 iters, error 4.94e-03
# iter = 1524
# vfi ends with 300 iters, error 7.18e-03
# iter = 1525
# vfi ends with 300 iters, error 5.67e-03
# iter = 1526
# vfi ends with 300 iters, error 7.02e-03
# iter = 1527
# vfi ends with 300 iters, error 8.72e-03
# iter = 1528
# vfi ends with 300 iters, error 1.17e-02
# iter = 1529
# vfi ends with 300 iters, error 1.46e-02
# iter = 1530
# vfi ends with 300 iters, error 1.31e-02
# iter = 1531
# vfi ends with 300 iters, error 5.98e-03
# iter = 1532
# vfi ends with 300 iters, error 7.76e-03
# iter = 1533
# vfi ends with 300 iters, error 1.37e-02
# iter = 1534
# vfi ends with 300 iters, error 1.00e-02
# iter = 1535
# vfi ends with 300 iters, error 1.15e-02
# iter = 1536
# vfi ends with 300 iters, error 5.09e-03
# iter = 1537
# vfi ends with 300 iters, error 7.55e-03
# iter = 1538
# vfi ends with 300 iters, error 7.63e-03
# iter = 1539
# vfi ends with 300 iters, error 9.70e-03
# iter = 1540
# vfi ends with 300 iters, error 7.89e-03
# iter = 1541
# vfi ends with 300 iters, error 4.75e-03
# iter = 1542
# vfi ends with 300 iters, error 5.06e-03
# iter = 1543
# vfi ends with 300 iters, error 7.47e-03
# iter = 1544
# vfi ends with 300 iters, error 7.21e-03
# iter = 1545
# vfi ends with 300 iters, error 9.40e-03
# iter = 1546
# vfi ends with 300 iters, error 1.37e-02
# iter = 1547
# vfi ends with 300 iters, error 6.46e-03
# iter = 1548
# vfi ends with 300 iters, error 7.61e-03
# iter = 1549
# vfi ends with 300 iters, error 7.03e-03
# iter = 1550
# vfi ends with 300 iters, error 8.36e-03
# iter = 1551
# vfi ends with 300 iters, error 5.98e-03
# iter = 1552
# vfi ends with 300 iters, error 9.01e-03
# iter = 1553
# vfi ends with 300 iters, error 1.20e-02
# iter = 1554
# vfi ends with 300 iters, error 1.48e-02
# iter = 1555
# vfi ends with 300 iters, error 2.33e-02
# iter = 1556
# vfi ends with 300 iters, error 5.07e-03
# iter = 1557
# vfi ends with 300 iters, error 8.50e-03
# iter = 1558
# vfi ends with 300 iters, error 9.47e-03
# iter = 1559
# vfi ends with 300 iters, error 1.59e-02
# iter = 1560
# vfi ends with 300 iters, error 1.19e-02
# iter = 1561
# vfi ends with 300 iters, error 4.75e-03
# iter = 1562
# vfi ends with 300 iters, error 6.46e-03
# iter = 1563
# vfi ends with 300 iters, error 8.78e-03
# iter = 1564
# vfi ends with 300 iters, error 1.19e-02
# iter = 1565
# vfi ends with 300 iters, error 1.18e-02
# iter = 1566
# vfi ends with 300 iters, error 4.62e-03
# iter = 1567
# vfi ends with 300 iters, error 6.30e-03
# iter = 1568
# vfi ends with 300 iters, error 6.30e-03
# iter = 1569
# vfi ends with 300 iters, error 7.87e-03
# iter = 1570
# vfi ends with 300 iters, error 7.78e-03
# iter = 1571
# vfi ends with 300 iters, error 1.52e-02
# iter = 1572
# vfi ends with 300 iters, error 4.99e-03
# iter = 1573
# vfi ends with 300 iters, error 8.25e-03
# iter = 1574
# vfi ends with 300 iters, error 7.11e-03
# iter = 1575
# vfi ends with 300 iters, error 9.00e-03
# iter = 1576
# vfi ends with 300 iters, error 6.99e-03
# iter = 1577
# vfi ends with 300 iters, error 1.13e-02
# iter = 1578
# vfi ends with 300 iters, error 1.62e-02
# iter = 1579
# vfi ends with 300 iters, error 1.61e-02
# iter = 1580
# vfi ends with 300 iters, error 1.44e-02
# iter = 1581
# vfi ends with 300 iters, error 6.81e-03
# iter = 1582
# vfi ends with 300 iters, error 1.01e-02
# iter = 1583
# vfi ends with 300 iters, error 1.33e-02
# iter = 1584
# vfi ends with 300 iters, error 1.38e-02
# iter = 1585
# vfi ends with 300 iters, error 1.34e-02
# iter = 1586
# vfi ends with 300 iters, error 6.56e-03
# iter = 1587
# vfi ends with 300 iters, error 7.93e-03
# iter = 1588
# vfi ends with 300 iters, error 9.42e-03
# iter = 1589
# vfi ends with 300 iters, error 1.08e-02
# iter = 1590
# vfi ends with 300 iters, error 1.11e-02
# iter = 1591
# vfi ends with 300 iters, error 3.57e-03
# iter = 1592
# vfi ends with 300 iters, error 6.61e-03
# iter = 1593
# vfi ends with 300 iters, error 7.39e-03
# iter = 1594
# vfi ends with 300 iters, error 1.03e-02
# iter = 1595
# vfi ends with 300 iters, error 9.89e-03
# iter = 1596
# vfi ends with 300 iters, error 1.50e-02
# iter = 1597
# vfi ends with 300 iters, error 6.14e-03
# iter = 1598
# vfi ends with 300 iters, error 6.81e-03
# iter = 1599
# vfi ends with 300 iters, error 8.14e-03
# iter = 1600
# vfi ends with 300 iters, error 1.41e-02
# iter = 1601
# vfi ends with 32 iters, error 8.82e-06
# iter = 1602
# vfi ends with 32 iters, error 9.30e-06
# iter = 1603
# vfi ends with 32 iters, error 9.54e-06
# iter = 1604
# vfi ends with 32 iters, error 8.82e-06
# iter = 1605
# vfi ends with 32 iters, error 9.06e-06
# iter = 1606
# vfi ends with 40 iters, error 8.58e-06
# iter = 1607
# vfi ends with 40 iters, error 8.58e-06
# iter = 1608
# vfi ends with 40 iters, error 8.58e-06
# iter = 1609
# vfi ends with 40 iters, error 8.58e-06
# iter = 1610
# vfi ends with 40 iters, error 8.58e-06
# iter = 1611
# vfi ends with 52 iters, error 8.11e-06
# iter = 1612
# vfi ends with 52 iters, error 8.58e-06
# iter = 1613
# vfi ends with 52 iters, error 8.58e-06
# iter = 1614
# vfi ends with 52 iters, error 8.11e-06
# iter = 1615
# vfi ends with 52 iters, error 8.58e-06
# iter = 1616
# vfi ends with 71 iters, error 9.06e-06
# iter = 1617
# vfi ends with 71 iters, error 9.06e-06
# iter = 1618
# vfi ends with 71 iters, error 9.06e-06
# iter = 1619
# vfi ends with 71 iters, error 9.06e-06
# iter = 1620
# vfi ends with 71 iters, error 9.06e-06
# iter = 1621
# vfi ends with 110 iters, error 9.54e-06
# iter = 1622
# vfi ends with 110 iters, error 9.54e-06
# iter = 1623
# vfi ends with 110 iters, error 9.54e-06
# iter = 1624
# vfi ends with 110 iters, error 9.54e-06
# iter = 1625
# vfi ends with 110 iters, error 9.54e-06
# iter = 1626
# vfi ends with 300 iters, error 2.33e-03
# iter = 1627
# vfi ends with 300 iters, error 7.75e-04
# iter = 1628
# vfi ends with 300 iters, error 1.39e-03
# iter = 1629
# vfi ends with 300 iters, error 2.80e-03
# iter = 1630
# vfi ends with 300 iters, error 3.69e-03
# iter = 1631
# vfi ends with 300 iters, error 8.83e-04
# iter = 1632
# vfi ends with 300 iters, error 1.66e-03
# iter = 1633
# vfi ends with 300 iters, error 4.23e-03
# iter = 1634
# vfi ends with 300 iters, error 4.34e-03
# iter = 1635
# vfi ends with 300 iters, error 4.36e-03
# iter = 1636
# vfi ends with 300 iters, error 3.31e-03
# iter = 1637
# vfi ends with 300 iters, error 3.08e-03
# iter = 1638
# vfi ends with 300 iters, error 2.09e-03
# iter = 1639
# vfi ends with 300 iters, error 3.02e-03
# iter = 1640
# vfi ends with 300 iters, error 3.06e-03
# iter = 1641
# vfi ends with 300 iters, error 6.10e-03
# iter = 1642
# vfi ends with 300 iters, error 6.88e-03
# iter = 1643
# vfi ends with 300 iters, error 6.06e-04
# iter = 1644
# vfi ends with 300 iters, error 3.84e-04
# iter = 1645
# vfi ends with 300 iters, error 5.82e-04
# iter = 1646
# vfi ends with 300 iters, error 9.24e-03
# iter = 1647
# vfi ends with 300 iters, error 5.63e-05
# iter = 1648
# vfi ends with 300 iters, error 3.73e-04
# iter = 1649
# vfi ends with 124 iters, error 9.54e-06
# iter = 1650
# vfi ends with 112 iters, error 9.54e-06
# iter = 1651
# vfi ends with 300 iters, error 4.96e-03
# iter = 1652
# vfi ends with 300 iters, error 3.04e-03
# iter = 1653
# vfi ends with 300 iters, error 8.14e-03
# iter = 1654
# vfi ends with 300 iters, error 6.96e-03
# iter = 1655
# vfi ends with 300 iters, error 7.86e-03
# iter = 1656
# vfi ends with 300 iters, error 4.46e-03
# iter = 1657
# vfi ends with 300 iters, error 4.90e-03
# iter = 1658
# vfi ends with 300 iters, error 4.11e-03
# iter = 1659
# vfi ends with 300 iters, error 7.43e-03
# iter = 1660
# vfi ends with 300 iters, error 6.68e-03
# iter = 1661
# vfi ends with 300 iters, error 5.70e-03
# iter = 1662
# vfi ends with 300 iters, error 4.03e-03
# iter = 1663
# vfi ends with 300 iters, error 4.53e-03
# iter = 1664
# vfi ends with 300 iters, error 8.22e-03
# iter = 1665
# vfi ends with 300 iters, error 8.59e-03
# iter = 1666
# vfi ends with 300 iters, error 9.10e-03
# iter = 1667
# vfi ends with 300 iters, error 1.02e-02
# iter = 1668
# vfi ends with 300 iters, error 3.74e-03
# iter = 1669
# vfi ends with 300 iters, error 4.88e-03
# iter = 1670
# vfi ends with 300 iters, error 5.27e-03
# iter = 1671
# vfi ends with 300 iters, error 1.09e-02
# iter = 1672
# vfi ends with 300 iters, error 4.43e-04
# iter = 1673
# vfi ends with 143 iters, error 8.58e-06
# iter = 1674
# vfi ends with 115 iters, error 7.63e-06
# iter = 1675
# vfi ends with 300 iters, error 4.29e-05
# iter = 1676
# vfi ends with 300 iters, error 7.18e-03
# iter = 1677
# vfi ends with 300 iters, error 4.26e-03
# iter = 1678
# vfi ends with 300 iters, error 7.57e-03
# iter = 1679
# vfi ends with 300 iters, error 9.66e-03
# iter = 1680
# vfi ends with 300 iters, error 1.22e-02
# iter = 1681
# vfi ends with 300 iters, error 5.53e-03
# iter = 1682
# vfi ends with 300 iters, error 6.70e-03
# iter = 1683
# vfi ends with 300 iters, error 6.74e-03
# iter = 1684
# vfi ends with 300 iters, error 8.10e-03
# iter = 1685
# vfi ends with 300 iters, error 1.50e-02
# iter = 1686
# vfi ends with 300 iters, error 7.86e-03
# iter = 1687
# vfi ends with 300 iters, error 4.47e-03
# iter = 1688
# vfi ends with 300 iters, error 5.37e-03
# iter = 1689
# vfi ends with 300 iters, error 6.11e-03
# iter = 1690
# vfi ends with 300 iters, error 1.03e-02
# iter = 1691
# vfi ends with 300 iters, error 7.25e-03
# iter = 1692
# vfi ends with 300 iters, error 1.04e-02
# iter = 1693
# vfi ends with 300 iters, error 4.65e-03
# iter = 1694
# vfi ends with 300 iters, error 6.43e-03
# iter = 1695
# vfi ends with 300 iters, error 6.29e-03
# iter = 1696
# vfi ends with 300 iters, error 1.24e-02
# iter = 1697
# vfi ends with 300 iters, error 9.07e-04
# iter = 1698
# vfi ends with 300 iters, error 3.73e-04
# iter = 1699
# vfi ends with 300 iters, error 4.53e-03
# iter = 1700
# vfi ends with 300 iters, error 6.72e-03
# iter = 1701
# vfi ends with 300 iters, error 5.39e-03
# iter = 1702
# vfi ends with 300 iters, error 7.10e-03
# iter = 1703
# vfi ends with 300 iters, error 7.42e-03
# iter = 1704
# vfi ends with 300 iters, error 1.09e-02
# iter = 1705
# vfi ends with 300 iters, error 1.77e-02
# iter = 1706
# vfi ends with 300 iters, error 6.52e-03
# iter = 1707
# vfi ends with 300 iters, error 8.56e-03
# iter = 1708
# vfi ends with 300 iters, error 6.18e-03
# iter = 1709
# vfi ends with 300 iters, error 8.56e-03
# iter = 1710
# vfi ends with 300 iters, error 1.36e-02
# iter = 1711
# vfi ends with 300 iters, error 9.65e-03
# iter = 1712
# vfi ends with 300 iters, error 4.96e-03
# iter = 1713
# vfi ends with 300 iters, error 7.40e-03
# iter = 1714
# vfi ends with 300 iters, error 7.03e-03
# iter = 1715
# vfi ends with 300 iters, error 8.42e-03
# iter = 1716
# vfi ends with 300 iters, error 7.28e-03
# iter = 1717
# vfi ends with 300 iters, error 1.22e-02
# iter = 1718
# vfi ends with 300 iters, error 5.35e-03
# iter = 1719
# vfi ends with 300 iters, error 6.82e-03
# iter = 1720
# vfi ends with 300 iters, error 8.64e-03
# iter = 1721
# vfi ends with 300 iters, error 1.47e-02
# iter = 1722
# vfi ends with 300 iters, error 2.98e-03
# iter = 1723
# vfi ends with 300 iters, error 8.85e-03
# iter = 1724
# vfi ends with 300 iters, error 8.43e-03
# iter = 1725
# vfi ends with 300 iters, error 8.72e-03
# iter = 1726
# vfi ends with 300 iters, error 6.08e-03
# iter = 1727
# vfi ends with 300 iters, error 9.83e-03
# iter = 1728
# vfi ends with 300 iters, error 1.50e-02
# iter = 1729
# vfi ends with 300 iters, error 1.93e-02
# iter = 1730
# vfi ends with 300 iters, error 2.09e-02
# iter = 1731
# vfi ends with 300 iters, error 4.37e-03
# iter = 1732
# vfi ends with 300 iters, error 1.02e-02
# iter = 1733
# vfi ends with 300 iters, error 1.09e-02
# iter = 1734
# vfi ends with 300 iters, error 9.53e-03
# iter = 1735
# vfi ends with 300 iters, error 1.19e-02
# iter = 1736
# vfi ends with 300 iters, error 6.03e-03
# iter = 1737
# vfi ends with 300 iters, error 4.90e-03
# iter = 1738
# vfi ends with 300 iters, error 7.21e-03
# iter = 1739
# vfi ends with 300 iters, error 9.27e-03
# iter = 1740
# vfi ends with 300 iters, error 8.62e-03
# iter = 1741
# vfi ends with 300 iters, error 8.56e-03
# iter = 1742
# vfi ends with 300 iters, error 1.25e-02
# iter = 1743
# vfi ends with 300 iters, error 7.53e-03
# iter = 1744
# vfi ends with 300 iters, error 6.47e-03
# iter = 1745
# vfi ends with 300 iters, error 7.60e-03
# iter = 1746
# vfi ends with 300 iters, error 1.68e-02
# iter = 1747
# vfi ends with 300 iters, error 6.59e-03
# iter = 1748
# vfi ends with 300 iters, error 7.28e-03
# iter = 1749
# vfi ends with 300 iters, error 9.53e-03
# iter = 1750
# vfi ends with 300 iters, error 8.40e-03
# iter = 1751
# vfi ends with 300 iters, error 7.55e-03
# iter = 1752
# vfi ends with 300 iters, error 9.05e-03
# iter = 1753
# vfi ends with 300 iters, error 1.33e-02
# iter = 1754
# vfi ends with 300 iters, error 1.03e-02
# iter = 1755
# vfi ends with 300 iters, error 2.27e-02
# iter = 1756
# vfi ends with 300 iters, error 8.43e-03
# iter = 1757
# vfi ends with 300 iters, error 9.20e-03
# iter = 1758
# vfi ends with 300 iters, error 1.29e-02
# iter = 1759
# vfi ends with 300 iters, error 1.60e-02
# iter = 1760
# vfi ends with 300 iters, error 1.18e-02
# iter = 1761
# vfi ends with 300 iters, error 1.02e-02
# iter = 1762
# vfi ends with 300 iters, error 6.96e-03
# iter = 1763
# vfi ends with 300 iters, error 8.50e-03
# iter = 1764
# vfi ends with 300 iters, error 1.14e-02
# iter = 1765
# vfi ends with 300 iters, error 9.96e-03
# iter = 1766
# vfi ends with 300 iters, error 8.90e-03
# iter = 1767
# vfi ends with 300 iters, error 5.94e-03
# iter = 1768
# vfi ends with 300 iters, error 7.25e-03
# iter = 1769
# vfi ends with 300 iters, error 1.07e-02
# iter = 1770
# vfi ends with 300 iters, error 8.35e-03
# iter = 1771
# vfi ends with 300 iters, error 1.71e-02
# iter = 1772
# vfi ends with 300 iters, error 6.21e-03
# iter = 1773
# vfi ends with 300 iters, error 5.57e-03
# iter = 1774
# vfi ends with 300 iters, error 6.69e-03
# iter = 1775
# vfi ends with 300 iters, error 1.05e-02
# iter = 1776
# vfi ends with 300 iters, error 9.96e-03
# iter = 1777
# vfi ends with 300 iters, error 1.01e-02
# iter = 1778
# vfi ends with 300 iters, error 1.01e-02
# iter = 1779
# vfi ends with 300 iters, error 1.92e-02
# iter = 1780
# vfi ends with 300 iters, error 1.32e-02
# iter = 1781
# vfi ends with 300 iters, error 6.38e-03
# iter = 1782
# vfi ends with 300 iters, error 1.01e-02
# iter = 1783
# vfi ends with 300 iters, error 1.23e-02
# iter = 1784
# vfi ends with 300 iters, error 1.10e-02
# iter = 1785
# vfi ends with 300 iters, error 1.43e-02
# iter = 1786
# vfi ends with 300 iters, error 6.40e-03
# iter = 1787
# vfi ends with 300 iters, error 7.61e-03
# iter = 1788
# vfi ends with 300 iters, error 8.86e-03
# iter = 1789
# vfi ends with 300 iters, error 9.61e-03
# iter = 1790
# vfi ends with 300 iters, error 1.39e-02
# iter = 1791
# vfi ends with 300 iters, error 8.98e-03
# iter = 1792
# vfi ends with 300 iters, error 5.11e-03
# iter = 1793
# vfi ends with 300 iters, error 6.10e-03
# iter = 1794
# vfi ends with 300 iters, error 8.95e-03
# iter = 1795
# vfi ends with 300 iters, error 9.31e-03
# iter = 1796
# vfi ends with 300 iters, error 2.02e-02
# iter = 1797
# vfi ends with 300 iters, error 8.32e-03
# iter = 1798
# vfi ends with 300 iters, error 6.09e-03
# iter = 1799
# vfi ends with 300 iters, error 7.18e-03
# iter = 1800
# vfi ends with 300 iters, error 9.03e-03
# iter = 1801
# vfi ends with 32 iters, error 8.82e-06

# %% [markdown]
# # Inspecting results

# %%
# These are the default parameters
@time main_gpu(
    build_ModelParams(
        nB=51, ny=21, T_longterm=20, T_sim=10^6, T_discard_sim=10^3, Bgrid_lb=1e-2, Bgrid_ub=2.5,
        σ=2., η=3., r=0.00598, ρ=0.9293, σ_ϵ=0.0115, θ=0.282, h=0.37,
        β=.83, β_hh=.9, α_m=1e-5, d0=-0.4, d1=0.43, λ=0., κ=0.,
        ρ_B=1e-3, ρ_μ=1e-3, ρ_δ=1e-3
        ), 
    max_iter=100, print_iter=0, sim_print="table", plot=0)

# %%
ny=Int32(51); ρ=0.9293f0; σ_ϵ=0.0115f0
grid, P = tauchen_carlo(ny, ρ, σ_ϵ)
ygrid = exp.(grid)

fn=21
figure(fn, figsize=(3,3), dpi=100)
clf()
ds = [
    0.       0.025;
    #-0.1    0.005;
    # -0.2    0.01;
    # -0.3    0.0125;
    # -0.4    0.005;
    # -0.5    0.02;
    ]
for i in 1:size(ds)[1]
    d0 = ds[i,1]
    d1 = -d0+ds[i,2]
    plot(ygrid, [y-max(0, d0*y+d1*y^2) for y in ygrid], label=@sprintf("d0=%.2f, d1=%.2f", d0, d1))
    # plot(model.ygrid, [max(0, d0*y+d1*y^2) for y in model.ygrid], label=@sprintf("d0=%.4f, d1=%.4f", d0, d1))
end
plot(ygrid, ygrid, ":k")
# plot(model.ygrid, zeros(model.ny), ":k")
title("Default Cost in terms of Output")
plot_style(fn)
